# %%
# read in preplacements.csv into a dataframe

import pandas as pd
import numpy as np

raw_indorm_df = pd.read_csv('indorm.csv')

# print(indorm_df.head(30))

# remove rows with no email or if 'In Dorm' is not in the list of dorms names
# 1: 'East',
# 2: 'North',
# 3: 'South',
# 4: 'West',
# 5: 'Atwood',
# 6: 'Sontag',
# 7: 'Case',
# 8: 'Drinkward',
# 9: 'Linde'

dorm_mapping = {
    'East': 1,
    'North': 2,
    'South': 3,
    'West': 4,
    'Atwood': 5,
    'Sontag': 6,
    'Case': 7,
    'Drinkward': 8,
    'Linde': 9
}

# remove rows where 'In Dorm' is not in the list of dorms
indorm_df = raw_indorm_df[raw_indorm_df['In Dorm'].isin(dorm_mapping.keys())]

# remove rows where email is empty
indorm_df = indorm_df[indorm_df['Email'].notna()]

# remove rows where 'In Dorm' is empty
indorm_df = indorm_df[indorm_df['In Dorm'].notna()]

print(indorm_df.head(5))

# print rows removed
print(pd.concat([indorm_df,raw_indorm_df]).drop_duplicates(keep=False))

# all emails ending in @hmc.edu modify to @g.hmc.edu and also remove any uppercase letters
indorm_df['Email'] = indorm_df['Email'].str.replace('@hmc.edu', '@g.hmc.edu')
indorm_df['Email'] = indorm_df['Email'].str.lower()

# print the first 5 rows of the dataframe
print(indorm_df.head(5))
# Out:
#          ID Name First Name Last In Dorm               Email
# 3  40215027      Talia       Yoo  Sontag      tyoo@g.hmc.edu
# 4  40215679    Natalie     Minor    Case    nminor@g.hmc.edu
# 5  40215680     Lilian       Zhu    Case    lilzhu@g.hmc.edu
# 7  40215774    Jessica     Huang  Sontag  jeshuang@g.hmc.edu
# 9  40215815    Miranda       Lau  Atwood      mlau@g.hmc.edu
#            ID Name First       Name Last In Dorm                    Email
# 0    40204574      Jacob         Glasser     NaN       vglasser@g.hmc.edu
# 1    40207673     Dwight            King     NaN         djking@g.hmc.edu
# 2    40210283       Jeff             Ren     NaN          jeren@g.hmc.edu
# 6    40215769    Rodrigo           Rosas     NaN         rrosas@g.hmc.edu
# 8    40215794       Finn        Pennings     NaN      fpennings@g.hmc.edu
# 42   40221248   Huanhuan           Huang     NaN       huahuang@g.hmc.edu
# 47   40221265      Helen          Randle     NaN        hrandle@g.hmc.edu
# 50   40221278       Bell            Zhou     NaN        belzhou@g.hmc.edu
# 52   40221282       Lily          Anfang     NaN        lanfang@g.hmc.edu
# 59   40221343       Evan          Siegel     NaN        esiegel@g.hmc.edu
# 60   40221350     Elliot          Bobrow     NaN        ebobrow@g.hmc.edu
# 62   40221354        Sam         Wheeler  South        swheeler@g.hmc.edu
# 67   40221402   Emmanuel          Raposo     NaN        eraposo@g.hmc.edu
# 84   40221505     Shadab          Sharif     NaN        ssharif@g.hmc.edu
# 103  40221840       Sara       Morishige     NaN     smorishige@g.hmc.edu
# 111  40221999       Siri              Xu     NaN          sirxu@g.hmc.edu
# 112  40222027   Cheyenne        Trujillo     NaN      ctrujillo@g.hmc.edu
# 125  40222514        Zoe              He     NaN            xhe@g.hmc.edu
# 142  40223371     Mansib          Rahman     NaN        mrahman@g.hmc.edu
# 147  40223419     Carlos  Ojeda de Silva     NaN  cojedadesilva@g.hmc.edu
# 151  40223488       Nyah        Hamilton     NaN      nhamilton@g.hmc.edu
# 153  40223514        Mia        Martinez     NaN     mimartinez@g.hmc.edu
# 155  40223579       Yuan          Garcia     NaN        ygarcia@g.hmc.edu
# 170  40223833        Aum     Pechkamnerd     NaN   apechkamnerd@g.hmc.edu
# 173  40224005     Rachel         Adorkor     NaN       radorkor@g.hmc.edu
# 176  40224118     Tzaara          Jauhar     NaN        tjauhar@g.hmc.edu
# 181  40224173   Fabricio          Chombo     NaN      fchombojr@g.hmc.edu
# 186  40224241       Mayu         Tatsumi     NaN       mtatsumi@g.hmc.edu
# 192  40224355       Andy              Xu     NaN          andxu@g.hmc.edu
# 193  40224384     Aabhas        Senapati     NaN      asenapati@g.hmc.edu
# 195  40224401     Jayden         Thadani     NaN       jthadani@g.hmc.edu
# 199  40224495       Ella             Joo     NaN           ejoo@g.hmc.edu
# 200  40224511        Hua            Yuan     NaN        huayuan@g.hmc.edu
# 204  40224880    Marcell         Gentles     NaN       mgentles@g.hmc.edu
# 209  40225058       Iris        Randolph     NaN      irandolph@g.hmc.edu
# 214  40225200     Nicole           Balsz     NaN         nbalsz@g.hmc.edu
# 219  40225552    Johnson              Ho     NaN         johnho@g.hmc.edu
# 225  40213761    Solomon           Cooke     NaN         scooke@g.hmc.edu
#          ID Name First Name Last In Dorm               Email
# 3  40215027      Talia       Yoo  Sontag      tyoo@g.hmc.edu
# 4  40215679    Natalie     Minor    Case    nminor@g.hmc.edu
# 5  40215680     Lilian       Zhu    Case    lilzhu@g.hmc.edu
# 7  40215774    Jessica     Huang  Sontag  jeshuang@g.hmc.edu
# 9  40215815    Miranda       Lau  Atwood      mlau@g.hmc.edu

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# import env variables
import os
from dotenv import load_dotenv
from pathlib import Path

# import libraries for ssh tunneling
import sshtunnel

dotenv_path = os.path.join(os.getcwd(), '.env')
print(dotenv_path)

load_dotenv(dotenv_path=dotenv_path, verbose=True)

sql_pass = os.environ.get('SQL_PASS')
sql_ip = os.environ.get('SQL_IP')
sql_db_name = os.environ.get('SQL_DB_NAME')
sql_user = os.environ.get('SQL_USER')

tunnel_host = os.environ.get('TUNNEL_HOST')
tunnel_port = os.environ.get('TUNNEL_PORT')
tunnel_user = os.environ.get('TUNNEL_USER')
tunnel_pass = os.environ.get('TUNNEL_PASS')

tunnel = sshtunnel.SSHTunnelForwarder(
    (tunnel_host, int(tunnel_port)),
    ssh_username=tunnel_user,
    ssh_password=tunnel_pass,
    remote_bind_address=(sql_ip, 5432)
)

# After starting the tunnel
tunnel.start()

# Get the local bind port that the tunnel is using
local_port = tunnel.local_bind_port

# Update connection string to use localhost and the tunneled port
CONNSTR = f'postgresql://{sql_user}:{sql_pass}@127.0.0.1:{local_port}/{sql_db_name}'

# Now create your SQLAlchemy engine with this connection string
engine = create_engine(CONNSTR)

# Test the connection
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print("Connection successful!")
# Out:
# /mnt/home/elli/workspaces/roomdraw/database/notebooks/.env
# /mnt/home/elli/workspaces/roomdraw/.venv/lib/python3.13/site-packages/paramiko/pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /mnt/home/elli/workspaces/roomdraw/.venv/lib/python3.13/site-packages/paramiko/transport.py:253: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,
# Connection successful!

# %%
with engine.connect() as connection:
    # loop through the dataframe and insert each row into the database
    for index, row in indorm_df.iterrows():
        # first select the user from the database to check if they exist and if they are a senior
        query = f"SELECT year FROM Users WHERE email = '{row['Email']}'"
        print(query)
        result = connection.execute(text(query))
        user_year = result.fetchone()[0]
        print(user_year)
        if user_year:
            # check if the user is a senior
            if user_year == 'senior':
                # for each row, get the dorm id from the dorm mapping and update user table
                dorm_id = dorm_mapping[row['In Dorm']]
                query = f"UPDATE Users SET in_dorm = {dorm_id} WHERE email = '{row['Email']}'"
                connection.execute(text(query))
            else:
                raise Exception(f"User {row['Email']} is not a senior")
        else:
            raise Exception(f"User {row['Email']} does not exist")
        
    connection.commit()
        
print("Successfully updated users in dorm")
tunnel.stop()
# Out:
# SELECT year FROM Users WHERE email = 'tyoo@g.hmc.edu'
# senior
# SELECT year FROM Users WHERE email = 'nminor@g.hmc.edu'
# senior
# SELECT year FROM Users WHERE email = 'lilzhu@g.hmc.edu'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4         # first select the user from the database to check if they exist and if they are a senior
#       5         query = f"SELECT year FROM Users WHERE email = '{row['Email']}'"
#       6         print(query)
#       7         result = connection.execute(text(query))
# ----> 8         user_year = result.fetchone()[0]
#       9         print(user_year)
#      10         if user_year:
#      11             # check if the user is a senior
#
# TypeError: 'NoneType' object is not subscriptable
