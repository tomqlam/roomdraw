# %%
# read in preplacements.csv into a dataframe

import pandas as pd
import numpy as np

raw_indorm_df = pd.read_csv('indorm.csv')

# print(indorm_df.head(30))

# remove rows with no email or if 'In Dorm' is not in the list of dorms names
# 1: 'East',
# 2: 'North',
# 3: 'South',
# 4: 'West',
# 5: 'Atwood',
# 6: 'Sontag',
# 7: 'Case',
# 8: 'Drinkward',
# 9: 'Linde'

dorm_mapping = {
    'East': 1,
    'North': 2,
    'South': 3,
    'West': 4,
    'Atwood': 5,
    'Sontag': 6,
    'Case': 7,
    'Drinkward': 8,
    'Linde': 9
}

# remove rows where 'Automatic InDorm' is empty or not in the list of dorms
indorm_df = raw_indorm_df[raw_indorm_df['Automatic InDorm'].notna()]
indorm_df = indorm_df[indorm_df['Automatic InDorm'].isin(dorm_mapping.keys())]

# remove rows where email is empty
indorm_df = indorm_df[indorm_df['Email'].notna()]

print(indorm_df.head(5))

# print rows removed
print(pd.concat([indorm_df,raw_indorm_df]).drop_duplicates(keep=False))

# all emails ending in @hmc.edu modify to @g.hmc.edu and also remove any uppercase letters
indorm_df['Email'] = indorm_df['Email'].str.replace('@hmc.edu', '@g.hmc.edu')
indorm_df['Email'] = indorm_df['Email'].str.lower()

# print the first 5 rows of the dataframe
print(indorm_df.head(5))
# Out:
#          ID Name First Name Last Automatic InDorm               Email
# 3  40215027      Talia       Yoo           Sontag      tyoo@g.hmc.edu
# 4  40215679    Natalie     Minor             Case    nminor@g.hmc.edu
# 5  40215680     Lilian       Zhu             Case    lilzhu@g.hmc.edu
# 7  40215774    Jessica     Huang           Sontag  jeshuang@g.hmc.edu
# 9  40215815    Miranda       Lau           Atwood      mlau@g.hmc.edu
#            ID Name First       Name Last Automatic InDorm  \
# 0    40204574      Jacob         Glasser              NaN
# 1    40207673     Dwight            King              NaN
# 2    40210283       Jeff             Ren              NaN
# 6    40215769    Rodrigo           Rosas              NaN
# 8    40215794       Finn        Pennings              NaN
# 42   40221248   Huanhuan           Huang              NaN
# 47   40221265      Helen          Randle              NaN
# 50   40221278       Bell            Zhou              NaN
# 52   40221282       Lily          Anfang              NaN
# 59   40221343       Evan          Siegel              NaN
# 60   40221350     Elliot          Bobrow              NaN
# 62   40221354        Sam         Wheeler           South
# 67   40221402   Emmanuel          Raposo              NaN
# 84   40221505     Shadab          Sharif              NaN
# 103  40221840       Sara       Morishige              NaN
# 111  40221999       Siri              Xu              NaN
# 112  40222027   Cheyenne        Trujillo              NaN
# 125  40222514        Zoe              He              NaN
# 142  40223371     Mansib          Rahman              NaN
# 147  40223419     Carlos  Ojeda de Silva              NaN
# 151  40223488       Nyah        Hamilton              NaN
# 153  40223514        Mia        Martinez              NaN
# 155  40223579       Yuan          Garcia              NaN
# 170  40223833        Aum     Pechkamnerd              NaN
# 173  40224005     Rachel         Adorkor              NaN
# 176  40224118     Tzaara          Jauhar              NaN
# 181  40224173   Fabricio          Chombo              NaN
# 186  40224241       Mayu         Tatsumi              NaN
# 192  40224355       Andy              Xu              NaN
# 193  40224384     Aabhas        Senapati              NaN
# 195  40224401     Jayden         Thadani              NaN
# 199  40224495       Ella             Joo              NaN
# 200  40224511        Hua            Yuan              NaN
# 204  40224880    Marcell         Gentles              NaN
# 209  40225058       Iris        Randolph              NaN
# 214  40225200     Nicole           Balsz              NaN
# 219  40225552    Johnson              Ho              NaN
# 225  40213761    Solomon           Cooke              NaN
#
#                        Email
# 0         vglasser@g.hmc.edu
# 1           djking@g.hmc.edu
# 2            jeren@g.hmc.edu
# 6           rrosas@g.hmc.edu
# 8        fpennings@g.hmc.edu
# 42        huahuang@g.hmc.edu
# 47         hrandle@g.hmc.edu
# 50         belzhou@g.hmc.edu
# 52         lanfang@g.hmc.edu
# 59         esiegel@g.hmc.edu
# 60         ebobrow@g.hmc.edu
# 62        swheeler@g.hmc.edu
# 67         eraposo@g.hmc.edu
# 84         ssharif@g.hmc.edu
# 103     smorishige@g.hmc.edu
# 111          sirxu@g.hmc.edu
# 112      ctrujillo@g.hmc.edu
# 125            xhe@g.hmc.edu
# 142        mrahman@g.hmc.edu
# 147  cojedadesilva@g.hmc.edu
# 151      nhamilton@g.hmc.edu
# 153     mimartinez@g.hmc.edu
# 155        ygarcia@g.hmc.edu
# 170   apechkamnerd@g.hmc.edu
# 173       radorkor@g.hmc.edu
# 176        tjauhar@g.hmc.edu
# 181      fchombojr@g.hmc.edu
# 186       mtatsumi@g.hmc.edu
# 192          andxu@g.hmc.edu
# 193      asenapati@g.hmc.edu
# 195       jthadani@g.hmc.edu
# 199           ejoo@g.hmc.edu
# 200        huayuan@g.hmc.edu
# 204       mgentles@g.hmc.edu
# 209      irandolph@g.hmc.edu
# 214         nbalsz@g.hmc.edu
# 219         johnho@g.hmc.edu
# 225         scooke@g.hmc.edu
#          ID Name First Name Last Automatic InDorm               Email
# 3  40215027      Talia       Yoo           Sontag      tyoo@g.hmc.edu
# 4  40215679    Natalie     Minor             Case    nminor@g.hmc.edu
# 5  40215680     Lilian       Zhu             Case    lilzhu@g.hmc.edu
# 7  40215774    Jessica     Huang           Sontag  jeshuang@g.hmc.edu
# 9  40215815    Miranda       Lau           Atwood      mlau@g.hmc.edu

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# import env variables
import os
from dotenv import load_dotenv
from pathlib import Path

# import libraries for ssh tunneling
import sshtunnel

dotenv_path = os.path.join(os.getcwd(), '.env')
print(dotenv_path)

load_dotenv(dotenv_path=dotenv_path, verbose=True)

sql_pass = os.environ.get('SQL_PASS')
sql_ip = os.environ.get('SQL_IP')
sql_db_name = os.environ.get('SQL_DB_NAME')
sql_user = os.environ.get('SQL_USER')

tunnel_host = os.environ.get('TUNNEL_HOST')
tunnel_port = os.environ.get('TUNNEL_PORT')
tunnel_user = os.environ.get('TUNNEL_USER')
tunnel_pass = os.environ.get('TUNNEL_PASS')

tunnel = sshtunnel.SSHTunnelForwarder(
    (tunnel_host, int(tunnel_port)),
    ssh_username=tunnel_user,
    ssh_password=tunnel_pass,
    remote_bind_address=(sql_ip, 5432)
)

# After starting the tunnel
tunnel.start()

# Get the local bind port that the tunnel is using
local_port = tunnel.local_bind_port

# Update connection string to use localhost and the tunneled port
CONNSTR = f'postgresql://{sql_user}:{sql_pass}@127.0.0.1:{local_port}/{sql_db_name}'

# Now create your SQLAlchemy engine with this connection string
engine = create_engine(CONNSTR)

# Test the connection
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print("Connection successful!")
# Out:
# /mnt/home/elli/workspaces/roomdraw/database/notebooks/.env
# /mnt/home/elli/workspaces/roomdraw/.venv/lib/python3.13/site-packages/paramiko/pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# /mnt/home/elli/workspaces/roomdraw/.venv/lib/python3.13/site-packages/paramiko/transport.py:253: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,
# Connection successful!
# WARNING:  database "roomdraw24" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.41, but the operating system provides version 2.42.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE roomdraw24 REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.

# %%
# with engine.connect() as connection:
#     connection.execute(text("UPDATE users SET in_dorm = 0"))
#     connection.commit()
#     print("Cleared in_dorm for all users")

# %%
not_found = []

with engine.connect() as connection:
    # loop through the dataframe and insert each row into the database
    for index, row in indorm_df.iterrows():
        # first select the user from the database to check if they exist and if they are a senior
        query = f"SELECT year FROM Users WHERE email = '{row['Email']}'"
        result = connection.execute(text(query))
        row_result = result.fetchone()

        if row_result is None:
            print(f"User {row['Email']} does not exist in the database, skipping")
            not_found.append({'Email': row['Email'], 'Automatic InDorm': row['Automatic InDorm']})
            continue

        user_year = row_result[0]
        if user_year == 'senior':
            dorm_id = dorm_mapping[row['Automatic InDorm']]
            query = f"UPDATE Users SET in_dorm = {dorm_id} WHERE email = '{row['Email']}'"
            connection.execute(text(query))
            print(f"Updated {row['Email']} in_dorm to {dorm_id}")
        else:
            print(f"User {row['Email']} is not a senior (year={user_year}), skipping")
            not_found.append({'Email': row['Email'], 'Automatic InDorm': row['Automatic InDorm']})
        
    connection.commit()

if not_found:
    pd.DataFrame(not_found).to_csv('not_found_indorm.csv', index=False)
    print(f"Wrote {len(not_found)} skipped users to not_found_indorm.csv")
        
print("Successfully updated users in dorm")
tunnel.stop()
# Out:
# Updated tyoo@g.hmc.edu in_dorm to 6
# Updated nminor@g.hmc.edu in_dorm to 7
# User lilzhu@g.hmc.edu does not exist in the database, skipping
# User jeshuang@g.hmc.edu does not exist in the database, skipping
# User mlau@g.hmc.edu does not exist in the database, skipping
# Updated oomoregbe@g.hmc.edu in_dorm to 9
# Updated whodges@g.hmc.edu in_dorm to 7
# User mibryan@g.hmc.edu does not exist in the database, skipping
# User stribble@g.hmc.edu does not exist in the database, skipping
# Updated ankrishnan@g.hmc.edu in_dorm to 6
# Updated mborg@g.hmc.edu in_dorm to 2
# Updated jngo@g.hmc.edu in_dorm to 6
# Updated than@g.hmc.edu in_dorm to 5
# Updated jheimann@g.hmc.edu in_dorm to 5
# Updated grwilliams@g.hmc.edu in_dorm to 8
# Updated elhernandez@g.hmc.edu in_dorm to 5
# Updated lhilkemeyer@g.hmc.edu in_dorm to 1
# Updated kyburns@g.hmc.edu in_dorm to 9
# Updated jiafu@g.hmc.edu in_dorm to 1
# Updated jholcombe@g.hmc.edu in_dorm to 1
# Updated lukewang@g.hmc.edu in_dorm to 8
# Updated ehoorn@g.hmc.edu in_dorm to 4
# Updated wcopeland@g.hmc.edu in_dorm to 2
# Updated lusullivan@g.hmc.edu in_dorm to 8
# Updated mpulling@g.hmc.edu in_dorm to 7
# Updated dipacheco@g.hmc.edu in_dorm to 4
# Updated sorobertson@g.hmc.edu in_dorm to 4
# Updated jikehara@g.hmc.edu in_dorm to 3
# Updated olli@g.hmc.edu in_dorm to 7
# Updated lchu@g.hmc.edu in_dorm to 2
# Updated bbownds@g.hmc.edu in_dorm to 4
# Updated ijain@g.hmc.edu in_dorm to 6
# Updated micobrien@g.hmc.edu in_dorm to 2
# Updated alezhu@g.hmc.edu in_dorm to 3
# Updated linnguyen@g.hmc.edu in_dorm to 6
# Updated annchang@g.hmc.edu in_dorm to 5
# Updated sscales@g.hmc.edu in_dorm to 5
# Updated csumino@g.hmc.edu in_dorm to 9
# Updated naigonzalez@g.hmc.edu in_dorm to 8
# Updated jmeraz@g.hmc.edu in_dorm to 4
# Updated soflores@g.hmc.edu in_dorm to 5
# User stxu@g.hmc.edu does not exist in the database, skipping
# Updated rsiguencia@g.hmc.edu in_dorm to 4
# Updated katlam@g.hmc.edu in_dorm to 5
# Updated pamcgraw@g.hmc.edu in_dorm to 2
# Updated brbownds@g.hmc.edu in_dorm to 4
# Updated alesilva@g.hmc.edu in_dorm to 9
# Updated jgong@g.hmc.edu in_dorm to 9
# Updated eambrizlazo@g.hmc.edu in_dorm to 7
# Updated anpandey@g.hmc.edu in_dorm to 5
# Updated ndass@g.hmc.edu in_dorm to 8
# Updated acary@g.hmc.edu in_dorm to 5
# User lordonez@g.hmc.edu does not exist in the database, skipping
# Updated olhubert@g.hmc.edu in_dorm to 5
# Updated skhuu@g.hmc.edu in_dorm to 8
# Updated clamalvarez@g.hmc.edu in_dorm to 7
# Updated gnetherton@g.hmc.edu in_dorm to 5
# Updated szaozerska@g.hmc.edu in_dorm to 5
# Updated lofowler@g.hmc.edu in_dorm to 2
# Updated syao@g.hmc.edu in_dorm to 8
# Updated dheredia@g.hmc.edu in_dorm to 5
# Updated arock@g.hmc.edu in_dorm to 8
# Updated rhaapala@g.hmc.edu in_dorm to 6
# Updated ediazramos@g.hmc.edu in_dorm to 9
# Updated lvlases@g.hmc.edu in_dorm to 5
# Updated edhernandez@g.hmc.edu in_dorm to 5
# Updated mabuchanan@g.hmc.edu in_dorm to 5
# Updated manortiz@g.hmc.edu in_dorm to 9
# Updated yorihuela@g.hmc.edu in_dorm to 7
# Updated allbarker@g.hmc.edu in_dorm to 5
# Updated tixie@g.hmc.edu in_dorm to 5
# Updated kacassidy@g.hmc.edu in_dorm to 5
# Updated amyliu01@g.hmc.edu in_dorm to 1
# Updated sellu@g.hmc.edu in_dorm to 6
# Updated casynnott@g.hmc.edu in_dorm to 3
# Wrote 11 skipped users to not_found_indorm.csv
# Successfully updated users in dorm
