# %%
# read in preplacements.csv into a dataframe

import pandas as pd
import numpy as np

df = pd.read_csv('preplacements.csv')


# Dorm Mapping
# 1 = East
# 2 = North
# 3 = South
# 4 = West
# 5 = Atwood
# 6 = Sontag
# 7 = Case
# 8 = Drinkward
# 9 = Linde
dorm_mapping = {
    'East': 1,
    'North': 2,
    'South': 3,
    'West': 4,
    'Atwood': 5,
    'Sontag': 6,
    'Case': 7,
    'Drinkward': 8,
    'Linde': 9,
    'Garrett House': 10
}

# remove any rows that don't have email, Dorm, or Room
df = df[df['Email'].notna() & df['Dorm'].notna() & df['Room'].notna()]

# remove any uppercase letters
df['Email'] = df['Email'].str.lower()
# if email ends in @hmc.edu, replace with @g.hmc.edu
df['Email'] = df['Email'].str.replace('@hmc.edu', '@g.hmc.edu')

# print the first 5 rows of the dataframe

# strip any whitespace from first name and last name and email and dorm and room
df['First Name'] = df['First Name'].str.strip()
df['Last Name'] = df['Last Name'].str.strip()
df['Email'] = df['Email'].str.strip()
df['Dorm'] = df['Dorm'].str.strip()
df['Room'] = df['Room'].str.strip()

# remove any rows that are not in the dorm mapping
df = df[df['Dorm'].isin(dorm_mapping.keys())]

print(df)
# Out:
#            ID First Name Last Name       Dorm  Room                 Email  \
# 6    40227057      Katie    Cooper      South  356C     kcooper@g.hmc.edu
# 7    40233040     Justin     Huang      South  304A     juhuang@g.hmc.edu
# 8    40235122       Alan   Lui-Sui      South  304B     aliusui@g.hmc.edu
# 9    40229679     London  Serratos      North   270   lserratos@g.hmc.edu
# 10   40225571        Max  Buchanan      North   220  mabuchanan@g.hmc.edu
# ..        ...        ...       ...        ...   ...                   ...
# 215  40236499      Tessa      Tsai  Drinkward   107      tetsai@g.hmc.edu
# 216  40235802       Coco      Peng  Drinkward   107      copeng@g.hmc.edu
# 217  40233148       Zach       Tan  Drinkward   314        ztan@g.hmc.edu
# 218  40235165     Thomas     Wylie  Drinkward   314      twylie@g.hmc.edu
# 219  40236826       Will     Klick  Drinkward   314      wklick@g.hmc.edu
#
#       Notes
# 6    Mentor
# 7    Mentor
# 8    Mentor
# 9    Mentor
# 10   Mentor
# ..      ...
# 215     NaN
# 216     NaN
# 217     NaN
# 218     NaN
# 219     NaN
#
# [204 rows x 7 columns]

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# import env variables
import os
from dotenv import load_dotenv
from pathlib import Path

# import libraries for ssh tunneling
import sshtunnel

dotenv_path = os.path.join(os.getcwd(), '.env')
print(dotenv_path)

load_dotenv(dotenv_path=dotenv_path, verbose=True)

sql_pass = os.environ.get('SQL_PASS')
sql_ip = os.environ.get('SQL_IP')
sql_db_name = os.environ.get('SQL_DB_NAME')
sql_user = os.environ.get('SQL_USER')

tunnel_host = os.environ.get('TUNNEL_HOST')
tunnel_port = os.environ.get('TUNNEL_PORT')
tunnel_user = os.environ.get('TUNNEL_USER')
tunnel_pass = os.environ.get('TUNNEL_PASS')

tunnel = sshtunnel.SSHTunnelForwarder(
    (tunnel_host, int(tunnel_port)),
    ssh_username=tunnel_user,
    ssh_password=tunnel_pass,
    remote_bind_address=(sql_ip, 5432)
)

# After starting the tunnel
tunnel.start()

# Get the local bind port that the tunnel is using
local_port = tunnel.local_bind_port

# Update connection string to use localhost and the tunneled port
CONNSTR = f'postgresql://{sql_user}:{sql_pass}@127.0.0.1:{local_port}/{sql_db_name}'

# Now create your SQLAlchemy engine with this connection string
engine = create_engine(CONNSTR)

# Test the connection
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print("Connection successful!")
# Out:
# /mnt/home/elli/workspaces/roomdraw/database/notebooks/.env
# Connection successful!
# WARNING:  database "roomdraw24" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.41, but the operating system provides version 2.42.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE roomdraw24 REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.

# %%
import requests
selection = input("Do you want to preplace in development or production? (dev/prod) ")
base_url = "http://localhost:8000/rooms/preplace/"
if selection != "dev" and selection != "prod":
    print("Invalid selection, please try again")
    exit()

if selection == "dev":
    base_url = "http://localhost:8000/rooms/preplace/"
else:
    base_url = "https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/"

admin_jwt = input("Please enter your admin JWT: ")

# link is localhost:8080/rooms/preplace/:roomuuid
# query the database to get all the rooms

# mapping of email to user id in the database
preplaced_user_ids = {}
room_ids = {}
with engine.connect() as connection:
    query = "SELECT room_uuid, dorm_name, room_id FROM rooms"
    result = connection.execute(text(query))
    # create a dictionary to store the room ids
    
    # loop through the result and add the room ids to the dictionary
    for row in result:
        room_ids[f'{row[1]} {row[2]}'] = row[0]
    query = "SELECT email, id FROM users WHERE preplaced = True"
    result = connection.execute(text(query))
    for row in result:
        preplaced_user_ids[row[0]] = row[1]
    connection.commit()
    
print(preplaced_user_ids)
print(room_ids)

not_found = []

# find all rows where the which share a common value for both Dorm and Room
# iterate through the groups that share a common value for both Dorm and Room and print the group
for name, group in df.groupby(['Dorm', 'Room']):
    if "Garrett House" in name:
        continue

    room_key = f'{name[0]} {name[1]}'
    if room_key not in room_ids:
        print(f"Room '{room_key}' not found in database, skipping")
        not_found.append({'reason': 'room not found', 'Dorm': name[0], 'Room': name[1], 'emails': ', '.join(group['Email'].tolist())})
        continue

    room_uuid = room_ids[room_key]
    print(f'Room UUID: {room_uuid}')

    users_in_group = group['Email'].tolist()
    print(users_in_group)

    # convert emails to user ids, skipping any not found in preplaced_user_ids
    proposed_occupants = []
    for email in users_in_group:
        if email not in preplaced_user_ids:
            print(f"User '{email}' not found in preplaced users, skipping")
            not_found.append({'reason': 'user not found', 'Dorm': name[0], 'Room': name[1], 'emails': email})
        else:
            proposed_occupants.append(preplaced_user_ids[email])

    if not proposed_occupants:
        print(f"No valid occupants for room '{room_key}', skipping")
        continue

    json_body = {
        'proposedOccupants': proposed_occupants,
        'userJWT': admin_jwt
    }

    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {admin_jwt}'
    }

    url = f'{base_url}{room_uuid}'
    print(url)

    response = requests.post(url, headers=headers, json=json_body)
    print(f"Response: {response.status_code}")

if not_found:
    pd.DataFrame(not_found).to_csv('not_found_preplacer.csv', index=False)
    print(f"Wrote {len(not_found)} skipped entries to not_found_preplacer.csv")
ce6db-aa70-402d-8016-fc93751c1558'), 'East 108': UUID('b32b392f-8894-405c-afd2-57c18834f5fb'), 'East 109': UUID('aaadc81f-8003-4a8c-817c-c05139382266'), 'East 111': UUID('eab246d8-6a55-4a74-951e-68211ef06ac0'), 'East 112': UUID('3e86d65f-dc5e-4252-aeba-e41caf37c89a'), 'East 110': UUID('2db17aa7-ecfa-4888-84c2-56d73d5a3869'), 'East 115': UUID('0d9d95de-dc5b-4dc5-8728-1f2988c593f3'), 'East 113': UUID('7bd9f13b-c879-471d-89e0-76c527899c9b'), 'East 114': UUID('c32829ef-c77c-4698-ba38-8d9514dda7aa'), 'East 116': UUID('eedca016-de01-4b2f-8e75-7267066832e8'), 'East 119': UUID('cf7fa01b-6f13-40b4-b0a6-1677ca1dde88'), 'East 123': UUID('2496a030-8d0c-4302-9f0d-0ff23da41765'), 'East 124': UUID('e4e8f06e-e478-4110-b2b4-78befc85dd7f'), 'East 120': UUID('6335b4f5-fc25-458f-8365-f60edc266212'), 'East 121': UUID('8428d7c0-f877-479f-8bd6-0c116e0ce950'), 'East 125': UUID('a339c3ff-609f-47b6-aa83-2a5f91c35cac'), 'East 126': UUID('9e6f663c-6df1-4a74-9db9-545955fa5aeb'), 'East 122': UUID('b7adb1fb-92b7-477b-9652-c224315617fe'), 'East 127': UUID('d9b92cd5-da10-41e4-8802-207ee4fab92d'), 'East 128': UUID('aaecf407-f2cd-4e14-8cda-708031b766c7'), 'East 151': UUID('7de8879f-a33d-4c9c-a3bc-7dc6706ffa02'), 'East 153': UUID('47332aa2-b66b-48cc-a7c7-ed61f49b4584'), 'East 154': UUID('3cee126a-cefc-4753-83b5-6aa6dfa95541'), 'East 152': UUID('79742b26-5e36-4672-bae0-b11849edafdd'), 'East 155': UUID('49efbd8e-e78a-4962-8965-a4d82a8fdbe2'), 'East 157': UUID('172cfe06-1775-44b0-acf1-a3ca60e4e892'), 'East 156': UUID('16910c24-a941-4fdc-bac0-06f0b29f75b7'), 'East 158': UUID('ac8748d2-a67d-42c5-a02b-a446f38ed4fd'), 'East 159': UUID('2248ce7c-527a-4205-a201-5368030e3fe6'), 'East 161': UUID('6672635c-c7c7-4803-a97e-8305f14ba486'), 'East 160': UUID('1c0b91d3-f244-448b-9c77-f49e91466ec0'), 'East 162': UUID('040147e0-fcd6-472b-af38-f4b5d9a46eb8'), 'East 165': UUID('21217367-70e6-429c-a019-606515566fe8'), 'East 163': UUID('ab464410-5f66-4c6b-bb80-57bfb1a64294'), 'East 166': UUID('c1b1b980-1af1-4bfb-887c-e8b4cea5f525'), 'East 164': UUID('4cbf16b6-fbb4-4355-bdca-62428889b97e'), 'East 169': UUID('58af696c-fb61-4f48-9fdb-b5425ae4c994'), 'East 173': UUID('f9316e52-4737-4f3d-9372-b404186caeea'), 'East 174': UUID('3188fa82-c46a-4ec4-9d75-655a14aac6d2'), 'East 170': UUID('f8ebd25c-290c-4e8e-a371-8dd61093605b'), 'East 175': UUID('a8a1939f-6d81-4574-bbd1-71d290e4fed8'), 'East 171': UUID('39e9e2f8-6821-4002-aeeb-0a345e3c8de4'), 'East 176': UUID('c4161ac1-2308-4258-85c0-74ada6a70a69'), 'East 172': UUID('620f25ab-a4cf-4294-9e1c-23affda33cf5'), 'East 177': UUID('e191bcd1-d722-49e1-a611-7d5593b5a512'), 'East 178': UUID('3a676b4a-3333-40d5-a573-7765354c31f1'), 'North 201': UUID('dcd9b03b-0fa4-4265-a616-50cd812e844a'), 'North 203': UUID('25611c76-0eed-408b-af24-8dfd5aded626'), 'North 204': UUID('20d65af5-7b32-40c9-9ed1-a1e130e57832'), 'North 202': UUID('d0882e07-0759-4bcf-9972-2df948470000'), 'North 207': UUID('31f7c4be-996d-44a7-999d-4d193db1775a'), 'North 205': UUID('4d056f01-2ffb-4a88-ad4a-ba00d23e3e84'), 'North 208': UUID('f2afeaf6-8c5f-4071-ab70-7d08209fbf79'), 'North 206': UUID('f99e7d86-6874-433f-9177-254b66ccdcee'), 'North 211': UUID('470b47a4-7fff-4d3d-8256-2eb5905bad09'), 'North 209': UUID('e5436c39-6f76-4f0f-a1ed-f667683c454c'), 'North 212': UUID('69d9150d-7ed9-40f3-b13a-816f3418bbda'), 'North 210': UUID('995dec06-348e-4afe-acf4-762bdd092709'), 'North 213': UUID('e6178e04-3a90-4be7-9178-aca39ac59e14'), 'North 215': UUID('182f2fbc-cc70-41f9-bd08-3a5eb6f98f96'), 'North 214': UUID('28affe9e-8eb3-41dc-894e-a357660601d3'), 'North 216': UUID('088c8cff-2a3c-4c49-ad63-318ec87dc4ec'), 'North 223': UUID('bb6b1695-4007-4254-9 ...
# Room UUID: 7b682803-234f-4ed3-8c0b-096691fa11ba
# ['jconjusteau@g.hmc.edu', 'mferits@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7b682803-234f-4ed3-8c0b-096691fa11ba
# Response: 200
# Room UUID: 8fe16669-78ab-4144-96e0-f7de8862fe9e
# ['sbone@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8fe16669-78ab-4144-96e0-f7de8862fe9e
# Response: 200
# Room UUID: b386b06a-e932-4f9d-acf6-c9eb407bd180
# ['emlo@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/b386b06a-e932-4f9d-acf6-c9eb407bd180
# Response: 200
# Room UUID: 7474d87c-5eb3-4680-bb6e-c1964e2d5a92
# ['jasmliu@g.hmc.edu', 'perodriguez@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7474d87c-5eb3-4680-bb6e-c1964e2d5a92
# Response: 200
# Room UUID: 956d6f76-be21-4b77-a704-62d9364587d2
# ['aprucnal@g.hmc.edu', 'sqiu@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/956d6f76-be21-4b77-a704-62d9364587d2
# Response: 200
# Room UUID: 009048c0-6d69-44f8-b620-c1d12a9ad08f
# ['nibhatt@g.hmc.edu', 'cmchenry@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/009048c0-6d69-44f8-b620-c1d12a9ad08f
# Response: 200
# Room UUID: 3471be6c-5012-400f-97ee-eb0b2870fcb8
# ['karipark@g.hmc.edu', 'carenas@g.hmc.edu']
# User 'carenas@g.hmc.edu' not found in preplaced users, skipping
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/3471be6c-5012-400f-97ee-eb0b2870fcb8
# Response: 200
# Room UUID: 99e6d628-0062-470b-ab86-d1eb179841c2
# ['hduncan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/99e6d628-0062-470b-ab86-d1eb179841c2
# Response: 200
# Room UUID: 16b185bc-5db2-44cd-ac39-02b26e260403
# ['ryanlee02@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/16b185bc-5db2-44cd-ac39-02b26e260403
# Response: 200
# Room UUID: 406e29d5-5567-41cc-97f6-09ffe5553969
# ['acarlino@g.hmc.edu', 'kiliang@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/406e29d5-5567-41cc-97f6-09ffe5553969
# Response: 200
# Room UUID: 8644208a-16b2-41c1-867f-223dfe30e685
# ['badili@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8644208a-16b2-41c1-867f-223dfe30e685
# Response: 200
# Room UUID: 8679b3a9-d3ec-452a-864f-8547858ee47a
# ['carodavis@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8679b3a9-d3ec-452a-864f-8547858ee47a
# Response: 200
# Room UUID: fc69acc3-1a40-4200-89a2-069b5e23dd3e
# ['jgrote@g.hmc.edu', 'syarlagadda@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/fc69acc3-1a40-4200-89a2-069b5e23dd3e
# Response: 200
# Room UUID: 9ee16e9f-7635-4c27-9007-ad9a3fa5795c
# ['cbrazelton@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/9ee16e9f-7635-4c27-9007-ad9a3fa5795c
# Response: 200
# Room UUID: 024e5700-04be-4a1a-8a27-5cda02db964f
# ['frjohnson@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/024e5700-04be-4a1a-8a27-5cda02db964f
# Response: 200
# Room UUID: fccfa34a-6e0d-4c54-b948-1f3431129ea8
# ['rpenidelema@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/fccfa34a-6e0d-4c54-b948-1f3431129ea8
# Response: 200
# Room UUID: 2f62988b-5682-424c-b385-0f7f8f75163e
# ['elihernandez@g.hmc.edu', 'zansari@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/2f62988b-5682-424c-b385-0f7f8f75163e
# Response: 200
# Room UUID: 7868ef25-be59-4758-8146-507e5b0653d4
# ['jibang@g.hmc.edu', 'bbui@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7868ef25-be59-4758-8146-507e5b0653d4
# Response: 200
# Room UUID: 3e1d9a9e-a9a7-42cd-ae96-a50151147f6e
# ['mconine@g.hmc.edu', 'estgonzalez@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/3e1d9a9e-a9a7-42cd-ae96-a50151147f6e
# Response: 200
# Room UUID: 69bb09c6-c726-49ce-80bc-e0a3c62de5ec
# ['rthillairajah@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/69bb09c6-c726-49ce-80bc-e0a3c62de5ec
# Response: 200
# Room UUID: 06763f6f-46ca-4646-a443-66d3089d7e53
# ['chrgonzalez@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/06763f6f-46ca-4646-a443-66d3089d7e53
# Response: 200
# Room UUID: 65088b48-354d-43cb-828b-e99dd861cba4
# ['jgonzalezsalgado@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/65088b48-354d-43cb-828b-e99dd861cba4
# Response: 200
# Room UUID: 9820491f-e864-47ad-8465-83de1d763630
# ['alrosenberg@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/9820491f-e864-47ad-8465-83de1d763630
# Response: 200
# Room UUID: ae00efb9-ac65-4647-a3d3-746d104008af
# ['catlee@g.hmc.edu', 'dkulkarni@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/ae00efb9-ac65-4647-a3d3-746d104008af
# Response: 200
# Room UUID: 489d747c-c727-476f-a540-94d7ae8c06e2
# ['eweir@g.hmc.edu', 'athaigarcia@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/489d747c-c727-476f-a540-94d7ae8c06e2
# Response: 200
# Room UUID: df920e16-d758-4929-a59d-a575cb5b0592
# ['dlhommedieu@g.hmc.edu', 'srutter@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/df920e16-d758-4929-a59d-a575cb5b0592
# Response: 200
# Room UUID: d6ab56e7-fb31-4f1b-82ec-b3f45db26a43
# ['jsesate@g.hmc.edu', 'sojayaweera@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d6ab56e7-fb31-4f1b-82ec-b3f45db26a43
# Response: 200
# Room UUID: e1df6a58-fda1-4e43-a14d-4e65e65e60ac
# ['mdavi@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/e1df6a58-fda1-4e43-a14d-4e65e65e60ac
# Response: 200
# Room UUID: d8b0814d-bfc8-4af6-a827-dcb2c22a78c5
# ['rburrow@g.hmc.edu', 'tchelew@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d8b0814d-bfc8-4af6-a827-dcb2c22a78c5
# Response: 200
# Room UUID: 2210ada2-3dff-496d-a0b6-361ede97abae
# ['greynolds@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/2210ada2-3dff-496d-a0b6-361ede97abae
# Response: 200
# Room UUID: 240e2584-e2c0-4743-8eb8-0858e46dff91
# ['smichaelson@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/240e2584-e2c0-4743-8eb8-0858e46dff91
# Response: 200
# Room UUID: d611e5cd-766c-4221-8a01-090146e8ae6a
# ['wmoller@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d611e5cd-766c-4221-8a01-090146e8ae6a
# Response: 200
# Room UUID: de4212c5-65e4-4f5b-ba2c-4dee39725e3c
# ['grmurray@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/de4212c5-65e4-4f5b-ba2c-4dee39725e3c
# Response: 200
# Room UUID: 38ca0504-4454-4830-ba69-830641de914d
# ['wortega@g.hmc.edu', 'ijimenezpineda@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/38ca0504-4454-4830-ba69-830641de914d
# Response: 200
# Room UUID: 39625833-3ffd-4e2b-aedb-d3a49499290c
# ['eesqueda@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/39625833-3ffd-4e2b-aedb-d3a49499290c
# Response: 200
# Room UUID: faa9cd78-949a-4d06-8908-93ce65846099
# ['nvelardealvarez@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/faa9cd78-949a-4d06-8908-93ce65846099
# Response: 200
# Room UUID: 040bd755-e10a-4bd9-87bb-50732d2438ef
# ['yye@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/040bd755-e10a-4bd9-87bb-50732d2438ef
# Response: 200
# Room UUID: 4cfdbfdb-6db5-49e0-814d-df147852bbd4
# ['vvanasdale@g.hmc.edu']
# User 'vvanasdale@g.hmc.edu' not found in preplaced users, skipping
# No valid occupants for room 'Case 251', skipping
# Room UUID: f356f07a-07be-41df-ac5a-b8b96a029f48
# ['trienhart@g.hmc.edu', 'khernandezalvarez@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/f356f07a-07be-41df-ac5a-b8b96a029f48
# Response: 200
# Room UUID: 0f61fe3d-1632-454c-bb56-c0c2ad08285e
# ['lumorgan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/0f61fe3d-1632-454c-bb56-c0c2ad08285e
# Response: 200
# Room UUID: 36aca83c-3743-4787-bc83-90b322627d29
# ['ledunn@g.hmc.edu', 'tetsai@g.hmc.edu', 'copeng@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/36aca83c-3743-4787-bc83-90b322627d29
# Response: 200
# Room UUID: 1ed6b8ef-beac-4aec-99b3-821d979f465b
# ['tmahesh@g.hmc.edu', 'gseverson@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/1ed6b8ef-beac-4aec-99b3-821d979f465b
# Response: 200
# Room UUID: 7efc84a8-4e73-4bbc-bad8-07189e45f936
# ['jadwong@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7efc84a8-4e73-4bbc-bad8-07189e45f936
# Response: 200
# Room UUID: 34cccde4-47ee-48fd-8e85-a6d8198178c3
# ['candrieuxamadei@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/34cccde4-47ee-48fd-8e85-a6d8198178c3
# Response: 200
# Room UUID: 5d8e05f8-4fc4-47e9-b287-b25145283f24
# ['atidmarsh@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/5d8e05f8-4fc4-47e9-b287-b25145283f24
# Response: 200
# Room UUID: c5a221e4-ee80-4b73-8cf3-6483bd63b285
# ['bsimpson@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/c5a221e4-ee80-4b73-8cf3-6483bd63b285
# Response: 200
# Room UUID: 1f196f35-5026-4b5c-8193-738d8073b32c
# ['skoneru@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/1f196f35-5026-4b5c-8193-738d8073b32c
# Response: 200
# Room UUID: 382eb75c-aa00-4abd-8964-1a530d81d086
# ['hrepp@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/382eb75c-aa00-4abd-8964-1a530d81d086
# Response: 200
# Room UUID: a183f286-29c1-4e84-ada5-3f7b092a7344
# ['jiakchen@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/a183f286-29c1-4e84-ada5-3f7b092a7344
# Response: 200
# Room UUID: a067f7b6-f93b-49f6-840b-b3ddfa118bd9
# ['kahn@g.hmc.edu', 'kelzhou@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/a067f7b6-f93b-49f6-840b-b3ddfa118bd9
# Response: 200
# Room UUID: c4198848-5115-4d28-becf-64909fd8d4dc
# ['tholman@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/c4198848-5115-4d28-becf-64909fd8d4dc
# Response: 200
# Room UUID: cd51f47e-afa5-4a44-83e9-e0bf34fcc567
# ['jknudson@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/cd51f47e-afa5-4a44-83e9-e0bf34fcc567
# Response: 200
# Room UUID: 80ad570c-d62c-4b7c-abbe-ccd649a721e1
# ['achowdhary@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/80ad570c-d62c-4b7c-abbe-ccd649a721e1
# Response: 200
# Room UUID: 87903699-9659-4360-9665-4aaa965ec445
# ['jsampat@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/87903699-9659-4360-9665-4aaa965ec445
# Response: 200
# Room UUID: 2e96a6b0-b712-43e5-9119-dbe772e4786b
# ['osalazar@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/2e96a6b0-b712-43e5-9119-dbe772e4786b
# Response: 200
# Room UUID: e0854d7f-4d4d-4771-95b0-7f661e86bd8a
# ['aabiswas@g.hmc.edu', 'tleoz@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/e0854d7f-4d4d-4771-95b0-7f661e86bd8a
# Response: 200
# Room UUID: de34bb6a-2440-4bf9-a3b4-549707ddef9f
# ['harrischen@g.hmc.edu', 'mpaek@g.hmc.edu', 'natnguyen@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/de34bb6a-2440-4bf9-a3b4-549707ddef9f
# Response: 200
# Room UUID: 6563bc20-955a-4701-b1d6-2a0b1e23fdd8
# ['juthompsoncox@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/6563bc20-955a-4701-b1d6-2a0b1e23fdd8
# Response: 200
# Room UUID: ee1dbb61-10c3-4a63-8037-6eadff5541fb
# ['agallade@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/ee1dbb61-10c3-4a63-8037-6eadff5541fb
# Response: 200
# Room UUID: 293cc250-d94b-4a3f-8d43-03be7f702b58
# ['tixie@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/293cc250-d94b-4a3f-8d43-03be7f702b58
# Response: 200
# Room UUID: 1f0eb45e-1df3-4dbf-834c-0bdc929da2c3
# ['kacheng@g.hmc.edu', 'pragupta@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/1f0eb45e-1df3-4dbf-834c-0bdc929da2c3
# Response: 200
# Room UUID: bbee7bc3-448a-43d8-90ec-8c72a425c21e
# ['resquivel@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/bbee7bc3-448a-43d8-90ec-8c72a425c21e
# Response: 200
# Room UUID: 8546dccf-c0fe-4309-a4db-8e33fd374d21
# ['grwilliams@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8546dccf-c0fe-4309-a4db-8e33fd374d21
# Response: 200
# Room UUID: 71b15724-64a2-4319-b752-f60f3461e86b
# ['aliceliu@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace
g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/40841e40-5e65-4d1a-83d3-77815d871faa
# Response: 200
# Room UUID: 52be5770-e71a-409e-adfa-c3182a963eae
# ['lofowler@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/52be5770-e71a-409e-adfa-c3182a963eae
# Response: 200
# Room UUID: 9a19bd07-8148-47e0-afca-a78750e1f60a
# ['zlevenberg@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/9a19bd07-8148-47e0-afca-a78750e1f60a
# Response: 200
# Room UUID: 42ce9110-2799-43ff-ac94-37b943b56dbe
# ['trhan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/42ce9110-2799-43ff-ac94-37b943b56dbe
# Response: 200
# Room UUID: 5a895461-cdd9-442e-972f-45bf00c555d6
# ['mtatsumi@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/5a895461-cdd9-442e-972f-45bf00c555d6
# Response: 200
# Room UUID: 8cb2fcee-819a-47fc-92eb-5ab607296846
# ['ehoen@g.hmc.edu', 'vichoi@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8cb2fcee-819a-47fc-92eb-5ab607296846
# Response: 200
# Room UUID: bcd785e0-0774-455c-811b-0cb03a521621
# ['byongphiphatwong@g.hmc.edu', 'lgiraldo@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/bcd785e0-0774-455c-811b-0cb03a521621
# Response: 200
# Room UUID: 0ddcb515-87c4-4a84-98d6-9b18fdb0e21e
# ['mandrews@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/0ddcb515-87c4-4a84-98d6-9b18fdb0e21e
# Response: 200
# Room UUID: 7e1f0cc7-b317-48ff-98d0-e51be0b3ab99
# ['breis@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7e1f0cc7-b317-48ff-98d0-e51be0b3ab99
# Response: 200
# Room UUID: 6a118a66-1df6-49ca-b067-cd0a46c65fdb
# ['alezhu@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/6a118a66-1df6-49ca-b067-cd0a46c65fdb
# Response: 200
# Room UUID: 90eedad5-3f6d-457a-b111-8e9b17f337a0
# ['aashby@g.hmc.edu', 'bjiao@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/90eedad5-3f6d-457a-b111-8e9b17f337a0
# Response: 200
# Room UUID: d51ac95a-4893-4cde-a114-74d2146e442b
# ['asenapati@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d51ac95a-4893-4cde-a114-74d2146e442b
# Response: 200
# Room UUID: caf71114-5327-4e43-9ad2-c459757853fa
# ['ankrishnan@g.hmc.edu', 'sgopalakrishnan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/caf71114-5327-4e43-9ad2-c459757853fa
# Response: 400
# Room UUID: 8c7e0380-56b3-4e8d-bca0-5800a7e5b9f2
# ['ijain@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8c7e0380-56b3-4e8d-bca0-5800a7e5b9f2
# Response: 200
# Room UUID: 0ee025aa-f545-4090-83ab-2f39790dd980
# ['jmaheshwari@g.hmc.edu', 'ctauro@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/0ee025aa-f545-4090-83ab-2f39790dd980
# Response: 200
# Room UUID: 5de09b22-e9de-45b9-a946-ff387156f093
# ['hanparker@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/5de09b22-e9de-45b9-a946-ff387156f093
# Response: 200
# Room UUID: 7ffd3151-d88d-40ff-bceb-6a16fad83b13
# ['ypeng@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7ffd3151-d88d-40ff-bceb-6a16fad83b13
# Response: 200
# Room UUID: bb9fc2d9-6a81-4253-a017-664dbcf9d744
# ['nqazi@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/bb9fc2d9-6a81-4253-a017-664dbcf9d744
# Response: 200
# Room UUID: d73c2b38-51c5-4034-b24d-1a4187a28f44
# ['kkitchen@g.hmc.edu', 'christili@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d73c2b38-51c5-4034-b24d-1a4187a28f44
# Response: 200
# Room UUID: 6fe1c696-9ede-43aa-a0a1-a9ed4419d3a1
# ['tkidd@g.hmc.edu', 'lmcgraw@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/6fe1c696-9ede-43aa-a0a1-a9ed4419d3a1
# Response: 200
# Room UUID: 01112e79-2a75-4490-91ad-3f055d8ea5db
# ['sanarayanan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/01112e79-2a75-4490-91ad-3f055d8ea5db
# Response: 200
# Room UUID: b5cb9b0b-b322-458b-be2b-bf5034260be1
# ['tjauhar@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/b5cb9b0b-b322-458b-be2b-bf5034260be1
# Response: 200
# Room UUID: 8649e04e-fe0d-4997-b29a-af3d20741612
# ['fpeng@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/8649e04e-fe0d-4997-b29a-af3d20741612
# Response: 200
# Room UUID: c4d9cf0c-e491-46b1-a8d0-d9c3b49229e2
# ['nhamilton@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/c4d9cf0c-e491-46b1-a8d0-d9c3b49229e2
# Response: 200
# Room UUID: 600d8283-fb17-4dfe-82e7-effaad95e692
# ['adavies@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/600d8283-fb17-4dfe-82e7-effaad95e692
# Response: 200
# Room UUID: a67a0c3f-5c86-4762-adf4-f0047610d7e0
# ['aheath@g.hmc.edu', 'alyhill@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/a67a0c3f-5c86-4762-adf4-f0047610d7e0
# Response: 200
# Room UUID: 7c329975-7802-4450-8791-16a240fde1cb
# ['joschan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7c329975-7802-4450-8791-16a240fde1cb
# Response: 200
# Room UUID: 3e25544b-48e0-47c9-8ac5-5eabf6eec05f
# ['lsands@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/3e25544b-48e0-47c9-8ac5-5eabf6eec05f
# Response: 200
# Room UUID: 897501b3-62bf-41b7-b0f2-9d8621003940
# ['juhuang@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/897501b3-62bf-41b7-b0f2-9d8621003940
# Response: 200
# Room UUID: 40539a48-5d56-444c-acd2-606812b4cd10
# ['aliusui@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/40539a48-5d56-444c-acd2-606812b4cd10
# Response: 200
# Room UUID: 7257f14d-4ad4-4f37-bde0-76effd85c1f9
# ['lelam@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7257f14d-4ad4-4f37-bde0-76effd85c1f9
# Response: 200
# Room UUID: 7bb5e07d-c072-4475-b82c-58c99a079798
# ['destran@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7bb5e07d-c072-4475-b82c-58c99a079798
# Response: 200
# Room UUID: 61659b5a-1eb4-4967-9bb7-a36aa52430e7
# ['cfarrell@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/61659b5a-1eb4-4967-9bb7-a36aa52430e7
# Response: 200
# Room UUID: 47d038a2-992d-4f7e-9aa8-6ace1a849afa
# ['loneil@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/47d038a2-992d-4f7e-9aa8-6ace1a849afa
# Response: 200
# Room UUID: 76735bc1-9ef6-4185-927c-059ca8c938ca
# ['frhuang@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/76735bc1-9ef6-4185-927c-059ca8c938ca
# Response: 200
# Room UUID: 42f40a61-4f07-4236-aa5e-4a7bba6c7484
# ['aliwong@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/42f40a61-4f07-4236-aa5e-4a7bba6c7484
# Response: 200
# Room UUID: 65f495de-6aab-4e6d-9deb-65ec12a399d9
# ['mcraig@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/65f495de-6aab-4e6d-9deb-65ec12a399d9
# Response: 200
# Room UUID: f2a97725-5f4a-4ce8-81e0-9c0682752903
# ['jvanderreis@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/f2a97725-5f4a-4ce8-81e0-9c0682752903
# Response: 200
# Room UUID: 49eca2b2-8b66-4435-8968-b3270ce9d187
# ['jikehara@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/49eca2b2-8b66-4435-8968-b3270ce9d187
# Response: 200
# Room UUID: f7e798ef-0369-477f-910c-9ed41d432136
# ['rdebarger@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/f7e798ef-0369-477f-910c-9ed41d432136
# Response: 200
# Room UUID: 3c1c420e-71b1-4fa6-b70f-a6d5d35b0239
# ['rlazorchak@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/3c1c420e-71b1-4fa6-b70f-a6d5d35b0239
# Response: 200
# Room UUID: 7fa862be-643e-458c-94d0-2ca782340f81
# ['arajan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/7fa862be-643e-458c-94d0-2ca782340f81
# Response: 200
# Room UUID: 16d3e532-ba67-4f92-aaa0-94f670c2cc3f
# ['cgoya@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/16d3e532-ba67-4f92-aaa0-94f670c2cc3f
# Response: 200
# Room UUID: 466b2147-ad33-47e5-8370-c5eae8bf1fbf
# ['kcooper@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/466b2147-ad33-47e5-8370-c5eae8bf1fbf
# Response: 200
# Room UUID: ff9d1e62-bec7-4e36-a392-ea2520b17e5c
# ['aliyuan@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/ff9d1e62-bec7-4e36-a392-ea2520b17e5c
# Response: 200
# Room UUID: 44bc2aed-afcd-484c-8f29-f8380b1c3cdb
# ['amyers@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/44bc2aed-afcd-484c-8f29-f8380b1c3cdb
# Response: 200
# Room UUID: c1aabecc-3d47-470c-81f2-a678a0f5ce6f
# ['kmyrick@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/c1aabecc-3d47-470c-81f2-a678a0f5ce6f
# Response: 200
# Room UUID: d7541f61-c99d-4363-8fe5-54b73026d360
# ['nbalsz@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d7541f61-c99d-4363-8fe5-54b73026d360
# Response: 200
# Room UUID: 12b2eca1-2dd8-42c1-a9bd-ba7250103692
# ['shdinesh@g.hmc.edu', 'abstewart@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/12b2eca1-2dd8-42c1-a9bd-ba7250103692
# Response: 200
# Room UUID: b21f0959-0247-4c44-a5aa-1828ab4371a6
# ['gseymour@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/b21f0959-0247-4c44-a5aa-1828ab4371a6
# Response: 200
# Room UUID: 338de33a-339a-47c0-91b3-6a9e1c117fc5
# ['cameyer@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/338de33a-339a-47c0-91b3-6a9e1c117fc5
# Response: 200
# Room UUID: bbd0d98a-5d16-406f-8fe9-1b02fb343773
# ['scaldwell@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/bbd0d98a-5d16-406f-8fe9-1b02fb343773
# Response: 200
# Room UUID: 03945ed8-5d3b-4b43-9ded-1d309284a6f8
# ['abaik@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/03945ed8-5d3b-4b43-9ded-1d309284a6f8
# Response: 200
# Room UUID: b5bd73a4-4c20-41df-93ed-2ae2b08cccc8
# ['edgrodriguez@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/b5bd73a4-4c20-41df-93ed-2ae2b08cccc8
# Response: 200
# Room UUID: 70c2a081-bcc2-4bad-982f-12a3e67b746c
# ['ehoorn@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/70c2a081-bcc2-4bad-982f-12a3e67b746c
# Response: 200
# Room UUID: 4732fc26-5e66-4361-8de6-115617d9ff68
# ['ashgreen@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/4732fc26-5e66-4361-8de6-115617d9ff68
# Response: 200
# Room UUID: dbc82c9c-f92f-4f9a-a0b1-a25a0df4de77
# ['fchombojr@g.hmc.edu']
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/dbc82c9c-f92f-4f9a-a0b1-a25a0df4de77
# Response: 200
# Wrote 2 skipped entries to not_found_preplacer.csv
