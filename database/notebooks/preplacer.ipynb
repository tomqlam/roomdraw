# %%
# read in preplacements.csv into a dataframe

import pandas as pd
import numpy as np

df = pd.read_csv('preplacements.csv')


# Dorm Mapping
# 1 = East
# 2 = North
# 3 = South
# 4 = West
# 5 = Atwood
# 6 = Sontag
# 7 = Case
# 8 = Drinkward
# 9 = Linde
dorm_mapping = {
    'East': 1,
    'North': 2,
    'South': 3,
    'West': 4,
    'Atwood': 5,
    'Sontag': 6,
    'Case': 7,
    'Drinkward': 8,
    'Linde': 9,
    'Garrett House': 10
}

# remove any rows that don't have email, Dorm, or Room
df = df[df['Email'].notna() & df['Dorm'].notna() & df['Room'].notna()]

# remove any uppercase letters
df['Email'] = df['Email'].str.lower()
# if email ends in @hmc.edu, replace with @g.hmc.edu
df['Email'] = df['Email'].str.replace('@hmc.edu', '@g.hmc.edu')

# print the first 5 rows of the dataframe

# strip any whitespace from first name and last name and email and dorm and room
df['First Name'] = df['First Name'].str.strip()
df['Last Name'] = df['Last Name'].str.strip()
df['Email'] = df['Email'].str.strip()
df['Dorm'] = df['Dorm'].str.strip()
df['Room'] = df['Room'].str.strip()

# remove any rows that are not in the dorm mapping
df = df[df['Dorm'].isin(dorm_mapping.keys())]

print(df)
# Out:
#            ID First Name Last Name       Dorm  Room                 Email  \
# 6    40227057      Katie    Cooper      South  356C     kcooper@g.hmc.edu
# 7    40233040     Justin     Huang      South  304A     juhuang@g.hmc.edu
# 8    40235122       Alan   Lui-Sui      South  304B     aliusui@g.hmc.edu
# 9    40229679     London  Serratos      North   270   lserratos@g.hmc.edu
# 10   40225571        Max  Buchanan      North   220  mabuchanan@g.hmc.edu
# ..        ...        ...       ...        ...   ...                   ...
# 215  40236499      Tessa      Tsai  Drinkward   107      tetsai@g.hmc.edu
# 216  40235802       Coco      Peng  Drinkward   107      copeng@g.hmc.edu
# 217  40233148       Zach       Tan  Drinkward   314        ztan@g.hmc.edu
# 218  40235165     Thomas     Wylie  Drinkward   314      twylie@g.hmc.edu
# 219  40236826       Will     Klick  Drinkward   314      wklick@g.hmc.edu
#
#       Notes
# 6    Mentor
# 7    Mentor
# 8    Mentor
# 9    Mentor
# 10   Mentor
# ..      ...
# 215     NaN
# 216     NaN
# 217     NaN
# 218     NaN
# 219     NaN
#
# [204 rows x 7 columns]

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# import env variables
import os
from dotenv import load_dotenv
from pathlib import Path

# import libraries for ssh tunneling
import sshtunnel

dotenv_path = os.path.join(os.getcwd(), '.env')
print(dotenv_path)

load_dotenv(dotenv_path=dotenv_path, verbose=True)

sql_pass = os.environ.get('SQL_PASS')
sql_ip = os.environ.get('SQL_IP')
sql_db_name = os.environ.get('SQL_DB_NAME')
sql_user = os.environ.get('SQL_USER')

tunnel_host = os.environ.get('TUNNEL_HOST')
tunnel_port = os.environ.get('TUNNEL_PORT')
tunnel_user = os.environ.get('TUNNEL_USER')
tunnel_pass = os.environ.get('TUNNEL_PASS')

tunnel = sshtunnel.SSHTunnelForwarder(
    (tunnel_host, int(tunnel_port)),
    ssh_username=tunnel_user,
    ssh_password=tunnel_pass,
    remote_bind_address=(sql_ip, 5432)
)

# After starting the tunnel
tunnel.start()

# Get the local bind port that the tunnel is using
local_port = tunnel.local_bind_port

# Update connection string to use localhost and the tunneled port
CONNSTR = f'postgresql://{sql_user}:{sql_pass}@127.0.0.1:{local_port}/{sql_db_name}'

# Now create your SQLAlchemy engine with this connection string
engine = create_engine(CONNSTR)

# Test the connection
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print("Connection successful!")
# Out:
# /mnt/home/elli/workspaces/roomdraw/database/notebooks/.env
# Connection successful!
# WARNING:  database "roomdraw24" has a collation version mismatch
# DETAIL:  The database was created using collation version 2.41, but the operating system provides version 2.42.
# HINT:  Rebuild all objects in this database that use the default collation and run ALTER DATABASE roomdraw24 REFRESH COLLATION VERSION, or build PostgreSQL with the right library version.

# %%
import requests
selection = input("Do you want to preplace in development or production? (dev/prod) ")
base_url = "http://localhost:8000/rooms/preplace/"
if selection != "dev" and selection != "prod":
    print("Invalid selection, please try again")
    exit()

if selection == "dev":
    base_url = "http://localhost:8000/rooms/preplace/"
else:
    base_url = "https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/"

admin_jwt = input("Please enter your admin JWT: ")

# link is localhost:8080/rooms/preplace/:roomuuid
# query the database to get all the rooms

# mapping of email to user id in the database
preplaced_user_ids = {}
room_ids = {}
with engine.connect() as connection:
    query = "SELECT room_uuid, dorm_name, room_id FROM rooms"
    result = connection.execute(text(query))
    # create a dictionary to store the room ids
    
    # loop through the result and add the room ids to the dictionary
    for row in result:
        room_ids[f'{row[1]} {row[2]}'] = row[0]
    query = "SELECT email, id FROM users WHERE preplaced = True"
    result = connection.execute(text(query))
    for row in result:
        preplaced_user_ids[row[0]] = row[1]
    connection.commit()
    
print(preplaced_user_ids)
print(room_ids)

not_found = []

# find all rows where the which share a common value for both Dorm and Room
# iterate through the groups that share a common value for both Dorm and Room and print the group
for name, group in df.groupby(['Dorm', 'Room']):
    if "Garrett House" in name:
        continue

    room_key = f'{name[0]} {name[1]}'
    if room_key not in room_ids:
        print(f"Room '{room_key}' not found in database, skipping")
        not_found.append({'reason': 'room not found', 'Dorm': name[0], 'Room': name[1], 'emails': ', '.join(group['Email'].tolist())})
        continue

    room_uuid = room_ids[room_key]
    print(f'Room UUID: {room_uuid}')

    users_in_group = group['Email'].tolist()

    # convert emails to user ids, skipping any not found in preplaced_user_ids
    proposed_occupants = []
    for email in users_in_group:
        if email not in preplaced_user_ids:
            print(f"User '{email}' not found in preplaced users, skipping")
            not_found.append({'reason': 'user not found', 'Dorm': name[0], 'Room': name[1], 'emails': email})
        else:
            proposed_occupants.append(preplaced_user_ids[email])

    if not proposed_occupants:
        print(f"No valid occupants for room '{room_key}', skipping")
        continue

    # check current occupants in DB against what the CSV says
    with engine.connect() as connection:
        result = connection.execute(
            text("SELECT occupants FROM rooms WHERE room_uuid = :uuid"),
            {'uuid': str(room_uuid)}
        ).fetchone()
        current_occupants = sorted(list(result[0])) if result and result[0] else []

    if sorted(proposed_occupants) == current_occupants:
        print(f"Room '{room_key}' already has correct occupants {proposed_occupants}, skipping")
        continue

    print(f"Room '{room_key}' mismatch — DB: {current_occupants}, CSV: {proposed_occupants}. Updating...")

    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {admin_jwt}'
    }

    # clear existing preplaced occupants first
    remove_url = f'{base_url.replace("/preplace/", "/preplace/remove/")}{room_uuid}'
    remove_response = requests.post(remove_url, headers=headers)
    if remove_response.status_code not in (200, 400):
        print(f"Unexpected response clearing room '{room_key}': {remove_response.status_code} {remove_response.text}")
    else:
        print(f"Cleared room '{room_key}': {remove_response.status_code}")

    json_body = {
        'proposedOccupants': proposed_occupants,
        'userJWT': admin_jwt
    }

    url = f'{base_url}{room_uuid}'
    print(url)

    response = requests.post(url, headers=headers, json=json_body)
    print(f"Response: {response.status_code}")

if not_found:
    pd.DataFrame(not_found).to_csv('not_found_preplacer.csv', index=False)
    print(f"Wrote {len(not_found)} skipped entries to not_found_preplacer.csv")
# Out:
# {'sojayaweera@g.hmc.edu': 3791, 'jmaheshwari@g.hmc.edu': 3946, 'ctauro@g.hmc.edu': 3947, 'tetsai@g.hmc.edu': 3956, 'copeng@g.hmc.edu': 3957, 'twylie@g.hmc.edu': 3959, 'wklick@g.hmc.edu': 3960, 'carenas@g.hmc.edu': 3962, 'vvanasdale@g.hmc.edu': 3961, 'abcdef@g.hmc.edu': 3759, 'abcde@g.hmc.edu': 3758, 'abc@g.hmc.edu': 3756, 'abcd@g.hmc.edu': 3757, 'syarlagadda@g.hmc.edu': 3781, 'mconine@g.hmc.edu': 3782, 'estgonzalez@g.hmc.edu': 3783, 'kcooper@g.hmc.edu': 3760, 'juhuang@g.hmc.edu': 3761, 'a@g.hmc.edu': 3754, 'ehoen@g.hmc.edu': 3775, 'fpeng@g.hmc.edu': 3774, 'ab@g.hmc.edu': 3755, 'jgrote@g.hmc.edu': 3780, 'hanparker@g.hmc.edu': 3777, 'hduncan@g.hmc.edu': 3778, 'vichoi@g.hmc.edu': 3776, 'shdinesh@g.hmc.edu': 3765, 'abstewart@g.hmc.edu': 3766, 'aliusui@g.hmc.edu': 3762, 'cake@g.hmc.edu': 3770, 'ashgreen@g.hmc.edu': 3769, 'edgrodriguez@g.hmc.edu': 3767, 'gseymour@g.hmc.edu': 3768, 'mleaf@g.hmc.edu': 3771, 'wortega@g.hmc.edu': 3788, 'lumorgan@g.hmc.edu': 3786, 'jiakchen@g.hmc.edu': 3787, 'jconjusteau@g.hmc.edu': 3784, 'eweir@g.hmc.edu': 3794, 'athaigarcia@g.hmc.edu': 3795, 'rburrow@g.hmc.edu': 3796, 'tchelew@g.hmc.edu': 3797, 'metran@g.hmc.edu': 3798, 'pmelendres@g.hmc.edu': 3800, 'catlee@g.hmc.edu': 3792, 'dkulkarni@g.hmc.edu': 3793, 'ijimenezpineda@g.hmc.edu': 3789, 'aprucnal@g.hmc.edu': 3868, 'joschan@g.hmc.edu': 3802, 'mferits@g.hmc.edu': 3785, 'bsimpson@g.hmc.edu': 3818, 'amrogers@g.hmc.edu': 3854, 'jibang@g.hmc.edu': 3856, 'dlhommedieu@g.hmc.edu': 3862, 'trienhart@g.hmc.edu': 3864, 'mtatsumi@g.hmc.edu': 3810, 'aashby@g.hmc.edu': 3833, 'armalik@g.hmc.edu': 3858, 'nibhatt@g.hmc.edu': 3860, 'candrieuxamadei@g.hmc.edu': 3831, 'jasmliu@g.hmc.edu': 3852, 'bbui@g.hmc.edu': 3857, 'bjiao@g.hmc.edu': 3834, 'jgonzalezsalgado@g.hmc.edu': 3825, 'nvelardealvarez@g.hmc.edu': 3827, 'alyhill@g.hmc.edu': 3840, 'abilello@g.hmc.edu': 3836, 'smorishige@g.hmc.edu': 3808, 'tjauhar@g.hmc.edu': 3812, 'mnavarrete@g.hmc.edu': 3822, 'rkong@g.hmc.edu': 3837, 'scorrea@g.hmc.edu': 3855, 'mcraig@g.hmc.edu': 3838, 'carodavis@g.hmc.edu': 3842, 'sbone@g.hmc.edu': 3814, 'eesqueda@g.hmc.edu': 3828, 'lanfang@g.hmc.edu': 3832, 'srutter@g.hmc.edu': 3863, 'khernandezalvarez@g.hmc.edu': 3865, 'tianzhang@g.hmc.edu': 3859, 'cmchenry@g.hmc.edu': 3861, 'jkapp@g.hmc.edu': 3821, 'amedak@g.hmc.edu': 3824, 'aheath@g.hmc.edu': 3839, 'adavies@g.hmc.edu': 3841, 'wmoller@g.hmc.edu': 3850, 'perodriguez@g.hmc.edu': 3853, 'christili@g.hmc.edu': 3848, 'grmurray@g.hmc.edu': 3851, 'lmcgraw@g.hmc.edu': 3846, 'tkidd@g.hmc.edu': 3845, 'kkitchen@g.hmc.edu': 3847, 'frjohnson@g.hmc.edu': 3815, 'chrgonzalez@g.hmc.edu': 3826, 'nko@g.hmc.edu': 3849, 'kacheng@g.hmc.edu': 3871, 'sqiu@g.hmc.edu': 3869, 'mpaek@g.hmc.edu': 3902, 'natnguyen@g.hmc.edu': 3903, 'resquivel@g.hmc.edu': 3876, 'nhamilton@g.hmc.edu': 3907, 'luriarte@g.hmc.edu': 3908, 'cfarrell@g.hmc.edu': 3897, 'hhekmat@g.hmc.edu': 3883, 'destran@g.hmc.edu': 3896, 'lgiraldo@g.hmc.edu': 3924, 'zmessenger@g.hmc.edu': 3904, 'elihernandez@g.hmc.edu': 3905, 'kiliang@g.hmc.edu': 3920, 'nbalsz@g.hmc.edu': 3873, 'helhong@g.hmc.edu': 3929, 'saraliu@g.hmc.edu': 3909, 'cgoya@g.hmc.edu': 3877, 'zansari@g.hmc.edu': 3906, 'frhuang@g.hmc.edu': 3885, 'harrischen@g.hmc.edu': 3901, 'karipark@g.hmc.edu': 3930, 'badili@g.hmc.edu': 3874, 'nbowman@g.hmc.edu': 3879, 'rlazorchak@g.hmc.edu': 3887, 'ychu@g.hmc.edu': 3916, 'juthompsoncox@g.hmc.edu': 3918, 'acarlino@g.hmc.edu': 3919, 'byongphiphatwong@g.hmc.edu': 3923, 'aliyuan@g.hmc.edu': 3881, 'aliwong@g.hmc.edu': 3911, 'lfuller@g.hmc.edu': 3914, 'smiao@g.hmc.edu': 3928, 'srico@g.hmc.edu': 3926, 'amyers@g.hmc.edu': 3927, 'rthillairajah@g.hmc.edu': 3895, 'hrepp@g.hmc.edu': 3894, 'pragupta@g.hmc.edu': 3872, 'livanova@g.hmc.edu': 3898, 'atin@g.hmc.edu': 3899, 'breis@g.hmc.edu': 3892, 'loneil@g.hmc.edu': 3889, 'phayward@g.hmc.edu': 3915, 'nqazi@g.hmc.edu': 3890, 'smichaelson@g.hmc.edu': 3880, 'fchombojr@g.hmc.edu': 3875, 'lelam@g.hmc.edu': 3870, 'ytai@g.hmc.edu': 3820, 'aliceliu@g.hmc.edu': 3936, 'atidmarsh@g.hmc.edu': 38 ...
# {'Atwood 200': UUID('bba22f33-bca8-47ee-986a-bec91b6a1634'), 'Atwood 300': UUID('dd509c92-adcf-4b7e-bfff-f6807ad62536'), 'Case 105': UUID('7111b4d9-4e5d-4e6e-a310-24296c27f144'), 'Case 140': UUID('63aca7ff-f67f-46b8-b6a1-5d9efba34679'), 'Case 218': UUID('46b7416f-56dc-4316-a57c-a5d8cb60d13d'), 'East 105': UUID('17b5c8af-a57e-4b62-a04e-a144a77f0b46'), 'Atwood 102': UUID('f9b91d19-1f6d-4dad-ad1c-53b3f8d5dbba'), 'Atwood 104': UUID('b89391f4-6a60-412e-8a0b-601f83102203'), 'Atwood 126': UUID('8fd8bee9-7aec-4db0-86ba-2bdae318ec5e'), 'Atwood 208': UUID('00f6e99e-a0da-4d43-965d-5d44050bd312'), 'Atwood 214': UUID('8b0b7925-e72b-4d11-9b8c-7029ac1976ae'), 'Atwood 302': UUID('a30260fa-0449-4cfb-bf5e-467f4cf831bd'), 'Atwood 311': UUID('7e004359-120a-4114-9621-d7b8f3b629e2'), 'Case 107': UUID('4d5923d2-83ef-4c8d-9059-4b9412b95288'), 'Case 121': UUID('f1915bea-857a-4ddd-ae9f-f0bbc7cf7080'), 'Case 143': UUID('0e9161ba-ddf1-4f38-9ab8-dfebdab111dd'), 'Case 201': UUID('d0b80ca4-eecc-4e98-a847-13e59f284ae5'), 'Case 221': UUID('849ac0db-aca9-4e1f-a680-e02f5b324e7a'), 'Case 241': UUID('7eac6b3e-bdab-4ce7-bda8-fca340f17546'), 'East 114': UUID('64a5830b-c1d8-4213-b254-2b180d813386'), 'East 120': UUID('cf3d39f9-6da1-4555-a9fd-b85edf462d80'), 'East 172': UUID('e8375d49-2591-45e2-9c9a-bcdb2608711d'), 'North 215': UUID('57d58c43-cb38-4015-8e8d-ae81eda61071'), 'North 276': UUID('22cc034d-6359-4c20-9e2b-f75b1e796d7d'), 'Sontag 202D': UUID('81e8a079-e96b-4f4b-9243-cf2c29f107cf'), 'South 301C': UUID('a91e157d-2b9e-4a2f-ae45-78706ccc2ebd'), 'Sontag 107B': UUID('0a43f8c5-ef16-408a-9c2b-08c5a1e89223'), 'North 272': UUID('2bfc2674-190c-4836-875c-c6eee4408c53'), 'East 170': UUID('a0da3960-fab2-488b-8a40-ba15410dbb0c'), 'North 213': UUID('6f95b4d4-54a9-4099-927b-ab36f1f32b8b'), 'Sontag 105D': UUID('fa2bbe4e-c372-4eef-beeb-129cb43daa5b'), 'East 176': UUID('22a51d65-b8b1-4789-9e9e-31319776025d'), 'Sontag 202C': UUID('d6a824dd-105b-4d27-82f1-4cbcff0f5e84'), 'North 270': UUID('9427e71b-fadd-46bc-b61b-6391639b0a25'), 'Sontag 103D': UUID('7f3e1926-c938-4872-ae8e-9105c8dac647'), 'South 304B': UUID('d89add9f-b8ed-4e6f-bdd1-25cf3fd3df3c'), 'Sontag 202A': UUID('1b40d416-3d61-45fb-9eab-0bbd9f02af11'), 'South 301D': UUID('0c46cd8c-ba3b-43dc-95d6-b12a95be365c'), 'South 355A': UUID('48a81487-9f8b-4bc8-a90e-042f7e2b2fa1'), 'West 469': UUID('5b584adb-fec5-4082-a926-1720db7de522'), 'West 420': UUID('8b82c3ca-5dbf-4527-8b5d-28086d85182b'), 'South 351B': UUID('16beb7c2-db39-4ebc-8695-d5f41c02337c'), 'South 358A': UUID('a58298f1-44e5-4fd6-99f7-471c55f82e77'), 'West 471': UUID('111e751d-dd02-4125-b1ec-5b4e07793631'), 'South 354A': UUID('84ffc8fa-758f-4483-8dc7-ed309db1fd41'), 'West 421': UUID('b6423023-74ae-4f4c-b1fb-102966ac72a6'), 'South 358B': UUID('3158c27a-b0e2-4362-ae3c-590fc34a593a'), 'West 452': UUID('f5664cbd-b23c-4c1d-9dc5-ab9599f3b6c0'), 'South 360': UUID('d3eba791-e0bd-446b-adb1-6e410e97791f'), 'Atwood 101': UUID('a62c1007-237a-4432-afe1-f545f2325c16'), 'South 307C': UUID('baff49cc-05f0-4196-b528-3cbdff2a88fc'), 'East 121': UUID('2d10b5e7-6339-4cb7-b4d7-8e61b72f7a73'), 'North 221': UUID('f3efed23-c577-4015-9f9c-a0dfc8f9fbbf'), 'North 271': UUID('f7aa9cb9-577c-4502-9099-479af0482aa9'), 'South 359': UUID('9b103fe7-53cb-441c-b392-c076cd5e4e13'), 'West 460': UUID('1c5ec69d-4e7d-451f-8c6c-f62b996e3c3d'), 'Drinkward 117': UUID('7efc84a8-4e73-4bbc-bad8-07189e45f936'), 'Drinkward 120A': UUID('0353aca1-d3c7-42ec-9469-d7d179c17ade'), 'Drinkward 101': UUID('18375744-3343-470b-9f73-a25598efa631'), 'Drinkward 113': UUID('772d0144-3e1b-4a1a-a6e0-bc9126e9f887'), 'Drinkward 111': UUID('f68ec03a-8e06-495a-afbe-c5ff38e3f70a'), 'Drinkward 102': UUID('1a40787b-dd8e-42e8-a0ef-3ff1e9bfd623'), 'Drinkward 116': UUID('59869545-ab1d-4f78-8451-b493937c8abc'), 'Drinkward 110': UUID('a9bdbd62-90a4-4357-889b-1fbecca848b4'), 'Drinkward 109': UUID('8a61162d-dfcc-49e1-8d48-2db3136057c3'), 'Drinkward 115': UUID('3e632d7c-de2b-4f32-aacc-c67732967e5d'), 'Drinkward 103': UUID('ed64e859-9208-425c-a89d-bdc69a79 ...
# Room UUID: a62c1007-237a-4432-afe1-f545f2325c16
# Room 'Atwood 101' mismatch — DB: [], CSV: [3784, 3785]. Updating...
# Unexpected response clearing room 'Atwood 101': 401 {"error":"Invalid token"}
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/a62c1007-237a-4432-afe1-f545f2325c16
# Response: 401
# Room UUID: f9b91d19-1f6d-4dad-ad1c-53b3f8d5dbba
# Room 'Atwood 102' already has correct occupants [3814], skipping
# Room UUID: b89391f4-6a60-412e-8a0b-601f83102203
# Room 'Atwood 104' already has correct occupants [3813], skipping
# Room UUID: 8fd8bee9-7aec-4db0-86ba-2bdae318ec5e
# Room 'Atwood 126' already has correct occupants [3852, 3853], skipping
# Room UUID: a9ac4617-d4e6-41f2-8c9f-c76568646fda
# Room 'Atwood 127' already has correct occupants [3868, 3869], skipping
# Room UUID: bba22f33-bca8-47ee-986a-bec91b6a1634
# Room 'Atwood 200' already has correct occupants [3860, 3861], skipping
# Room UUID: 78e4b9ad-3eef-4782-b028-4a3e64e0861c
# Room 'Atwood 201' already has correct occupants [3930, 3962], skipping
# Room UUID: 6ff77e01-a519-4acb-a259-e78e803294d4
# Room 'Atwood 203' already has correct occupants [3778], skipping
# Room UUID: 00f6e99e-a0da-4d43-965d-5d44050bd312
# Room 'Atwood 208' already has correct occupants [3779], skipping
# Room UUID: 8b0b7925-e72b-4d11-9b8c-7029ac1976ae
# Room 'Atwood 214' already has correct occupants [3919, 3920], skipping
# Room UUID: da5751ab-259d-4333-89eb-9fe1ab565a96
# Room 'Atwood 224' already has correct occupants [3874], skipping
# Room UUID: 599a9034-16f3-4c1f-b305-db87a56f31c1
# Room 'Atwood 226' already has correct occupants [3842], skipping
# Room UUID: dd509c92-adcf-4b7e-bfff-f6807ad62536
# Room 'Atwood 300' already has correct occupants [3780, 3781], skipping
# Room UUID: a30260fa-0449-4cfb-bf5e-467f4cf831bd
# Room 'Atwood 302' already has correct occupants [3816], skipping
# Room UUID: af26ce07-66a8-491f-9e83-0d183a24e877
# Room 'Atwood 304' already has correct occupants [3815], skipping
# Room UUID: 7e004359-120a-4114-9621-d7b8f3b629e2
# Room 'Atwood 311' already has correct occupants [3934], skipping
# Room UUID: 26efdca9-6529-4d3e-a7e5-6e56bba592b7
# Room 'Atwood 312' already has correct occupants [3905, 3906], skipping
# Room UUID: a8db801f-2d22-497d-8d5d-df67c8ae5e83
# Room 'Atwood 314' already has correct occupants [3856, 3857], skipping
# Room UUID: 82efd4f1-b9e6-4950-9184-6c6f2436bd1c
# Room 'Atwood 327' already has correct occupants [3782, 3783], skipping
# Room UUID: 7111b4d9-4e5d-4e6e-a310-24296c27f144
# Room 'Case 105' already has correct occupants [3895], skipping
# Room UUID: 4d5923d2-83ef-4c8d-9059-4b9412b95288
# Room 'Case 107' already has correct occupants [3828], skipping
# Room UUID: 77447965-3f8b-49f9-91ad-adc0d54d75aa
# Room 'Case 108' already has correct occupants [3827], skipping
# Room UUID: f1915bea-857a-4ddd-ae9f-f0bbc7cf7080
# Room 'Case 121' already has correct occupants [3925], skipping
# Room UUID: f5248a26-4bec-43e1-b584-047eb6fa377c
# Room 'Case 123' already has correct occupants [3792, 3793], skipping
# Room UUID: b4c7c9ad-3eee-4da4-9c43-31d20040658c
# Room 'Case 124' already has correct occupants [3794, 3795], skipping
# Room UUID: 63aca7ff-f67f-46b8-b6a1-5d9efba34679
# Room 'Case 140' already has correct occupants [3862, 3863], skipping
# Room UUID: 0e9161ba-ddf1-4f38-9ab8-dfebdab111dd
# Room 'Case 143' already has correct occupants [3790, 3791], skipping
# Room UUID: 89fabb92-ec9d-4e7f-bf49-cab4b6cceb0a
# Room 'Case 154' already has correct occupants [3866], skipping
# Room UUID: d0b80ca4-eecc-4e98-a847-13e59f284ae5
# Room 'Case 201' already has correct occupants [3796, 3797], skipping
# Room UUID: 9e676f79-a908-42a5-93f0-4ee2494ed5e0
# Room 'Case 205' already has correct occupants [3878], skipping
# Room UUID: 138f878b-35b8-4c7c-a1c3-2ceac1ecd1b2
# Room 'Case 206' already has correct occupants [3880], skipping
# Room UUID: 46b7416f-56dc-4316-a57c-a5d8cb60d13d
# Room 'Case 218' already has correct occupants [3850], skipping
# Room UUID: 849ac0db-aca9-4e1f-a680-e02f5b324e7a
# Room 'Case 221' already has correct occupants [3851], skipping
# Room UUID: 7eac6b3e-bdab-4ce7-bda8-fca340f17546
# Room 'Case 241' already has correct occupants [3788, 3789], skipping
# Room UUID: 49c5e1b1-fec7-4d89-9f4d-e0cb04bc0213
# Room 'Case 246' already has correct occupants [3826], skipping
# Room UUID: fd9c58a8-92e0-41dc-8e95-ec7749ac15c0
# Room 'Case 247' already has correct occupants [3825], skipping
# Room UUID: 82ead2f6-0802-4dac-b513-ec6b08a9c9e9
# Room 'Case 250' already has correct occupants [3913], skipping
# Room UUID: 761bf9b5-c7b7-40a5-81f7-53577572231c
# Room 'Case 251' already has correct occupants [3961], skipping
# Room UUID: 5542a23e-979e-4999-9f77-d99c1457b045
# Room 'Case 252' already has correct occupants [3864, 3865], skipping
# Room UUID: 0f61fe3d-1632-454c-bb56-c0c2ad08285e
# Room 'Drinkward 105' already has correct occupants [3786], skipping
# Room UUID: 36aca83c-3743-4787-bc83-90b322627d29
# Room 'Drinkward 107' already has correct occupants [3955, 3956, 3957], skipping
# Room UUID: 1ed6b8ef-beac-4aec-99b3-821d979f465b
# Room 'Drinkward 108' already has correct occupants [3939, 3940], skipping
# Room UUID: 7efc84a8-4e73-4bbc-bad8-07189e45f936
# Room 'Drinkward 117' already has correct occupants [3912], skipping
# Room UUID: 34cccde4-47ee-48fd-8e85-a6d8198178c3
# Room 'Drinkward 123E' already has correct occupants [3831], skipping
# Room UUID: 5d8e05f8-4fc4-47e9-b287-b25145283f24
# Room 'Drinkward 124D' already has correct occupants [3817], skipping
# Room UUID: c5a221e4-ee80-4b73-8cf3-6483bd63b285
# Room 'Drinkward 124E' already has correct occupants [3818], skipping
# Room UUID: 1f196f35-5026-4b5c-8193-738d8073b32c
# Room 'Drinkward 201' already has correct occupants [3886], skipping
# Room UUID: 382eb75c-aa00-4abd-8964-1a530d81d086
# Room 'Drinkward 204' already has correct occupants [3894], skipping
# Room UUID: a183f286-29c1-4e84-ada5-3f7b092a7344
# Room 'Drinkward 205' already has correct occupants [3787], skipping
# Room UUID: a067f7b6-f93b-49f6-840b-b3ddfa118bd9
# Room 'Drinkward 207' already has correct occupants [3953, 3954], skipping
# Room UUID: c4198848-5115-4d28-becf-64909fd8d4dc
# Room 'Drinkward 212' already has correct occupants [3941], skipping
# Room UUID: cd51f47e-afa5-4a44-83e9-e0bf34fcc567
# Room 'Drinkward 213' already has correct occupants [3945], skipping
# Room UUID: 80ad570c-d62c-4b7c-abbe-ccd649a721e1
# Room 'Drinkward 214' already has correct occupants [3944], skipping
# Room UUID: 87903699-9659-4360-9665-4aaa965ec445
# Room 'Drinkward 216' already has correct occupants [3943], skipping
# Room UUID: 2e96a6b0-b712-43e5-9119-dbe772e4786b
# Room 'Drinkward 220' already has correct occupants [3942], skipping
# Room UUID: e0854d7f-4d4d-4771-95b0-7f661e86bd8a
# Room 'Drinkward 222C' already has correct occupants [3931, 3932], skipping
# Room UUID: de34bb6a-2440-4bf9-a3b4-549707ddef9f
# Room 'Drinkward 223C' already has correct occupants [3901, 3902, 3903], skipping
# Room UUID: 6563bc20-955a-4701-b1d6-2a0b1e23fdd8
# Room 'Drinkward 223D' already has correct occupants [3918], skipping
# Room UUID: ee1dbb61-10c3-4a63-8037-6eadff5541fb
# Room 'Drinkward 223E' already has correct occupants [3922], skipping
# Room UUID: 293cc250-d94b-4a3f-8d43-03be7f702b58
# Room 'Drinkward 223F' already has correct occupants [3900], skipping
# Room UUID: 1f0eb45e-1df3-4dbf-834c-0bdc929da2c3
# Room 'Drinkward 224C' already has correct occupants [3871, 3872], skipping
# Room UUID: bbee7bc3-448a-43d8-90ec-8c72a425c21e
# Room 'Drinkward 301' mismatch — DB: [], CSV: [3876]. Updating...
# Unexpected response clearing room 'Drinkward 301': 401 {"error":"Invalid token"}
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/bbee7bc3-448a-43d8-90ec-8c72a425c21e
# Response: 401
# Room UUID: 8546dccf-c0fe-4309-a4db-8e33fd374d21
# Room 'Drinkward 303' already has correct occupants [3910], skipping
# Room UUID: 71b15724-64a2-4319-b752-f60f3461e86b
# Room 'Drinkward 309' already has correct occupants [3936], skipping
# Room UUID: 523caf6d-afbe-470d-a32a-2c564cc9ef6b
# Room 'Drinkward 314' already has correct occupants [3958, 3959, 3960], skipping
# Room UUID: f840ee7d-0381-457a-b24d-d506d2881b45
# Room 'Drinkward 317' already has correct occupants [3883], skipping
# Room UUID: ef33f469-e960-4ee1-8024-cf460803814c
# Room 'Drinkward 318' already has correct occupants [3928, 3929], skipping
# Room UUID: 5c21c38f-ec92-454d-9579-108cb1659425
# Room 'Drinkward 319' already has correct occupants [3937, 3938], skipping
# Room UUID: b2ca9d25-a8b1-41f9-9872-16438d727aa7
# Room 'Drinkward 321D' already has correct occupants [3819], skipping
# Room UUID: 92ffff8b-dacd-44b0-8e6f-83e2e490e550
# Room 'Drinkward 321E' already has correct occupants [3820], skipping
# Room UUID: a87e0f3d-5cc2-44aa-a618-54453a3b120c
# Room 'Drinkward 322C' already has correct occupants [3914, 3915, 3916], skipping
# Room UUID: 291289d1-d66c-45ac-b068-b81770f7f0c0
# Room 'Drinkward 322E' already has correct occupants [3904], skipping
# Room UUID: 5e1cb87d-b1e2-4355-a50b-49101b45efe4
# Room 'Drinkward 324C' already has correct occupants [3898, 3899], skipping
# Room UUID: 9e7d6404-39e9-4230-9a9d-e2e04f2819a6
# Room 'Drinkward 324D' already has correct occupants [3935], skipping
# Room UUID: c2d8faff-c16c-4c06-9708-0fdab116e402
# Room 'Drinkward 324E' already has correct occupants [3921], skipping
# Room UUID: 3bff2b95-9b05-44a0-a267-b4def1ed55b2
# Room 'Drinkward 324F' already has correct occupants [3832], skipping
# Room UUID: 17b5c8af-a57e-4b62-a04e-a144a77f0b46
# Room 'East 105' already has correct occupants [3948], skipping
# Room UUID: 64a5830b-c1d8-4213-b254-2b180d813386
# Room 'East 114' already has correct occupants [3836, 3837], skipping
# Room UUID: f112ea13-c78d-4988-ace3-1fa0ab9f2c4e
# Room 'East 119' already has correct occupants [3849], skipping
# Room UUID: cf3d39f9-6da1-4555-a9fd-b85edf462d80
# Room 'East 120' already has correct occupants [3771], skipping
# Room UUID: e9e989cb-e97b-40df-8d6a-13104417990c
# Room 'East 123' already has correct occupants [3770], skipping
# Room UUID: a222dc14-d771-42ed-8cd6-9604d6d013af
# Room 'East 124' already has correct occupants [3879], skipping
# Room UUID: cc39b891-06d4-4f10-b0b8-793b9c267aa4
# Room 'East 153' already has correct occupants [3908, 3909], skipping
# Room UUID: 09eeb2e9-f4f9-4e2a-875f-d87b4b09fda3
# Room 'East 164' mismatch — DB: [], CSV: [3902]. Updating...
# Unexpected response clearing room 'East 164': 401 {"error":"Invalid token"}
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/09eeb2e9-f4f9-4e2a-875f-d87b4b09fda3
# Response: 401
# Room UUID: a0da3960-fab2-488b-8a40-ba15410dbb0c
# Room 'East 170' already has correct occupants [3772], skipping
# Room UUID: e8375d49-2591-45e2-9c9a-bcdb2608711d
# Room 'East 172' already has correct occupants [3808], skipping
# Room UUID: dc192fa4-67e5-46aa-bfbc-89e51aa609e9
# Room 'East 174' already has correct occupants [3773], skipping
# Room UUID: 22a51d65-b8b1-4789-9e9e-31319776025d
# Room 'East 176' already has correct occupants [3807], skipping
# Room UUID: 8b18a876-db70-4922-85d7-2ad41f5b1a90
# Room 'Linde 101' already has correct occupants [3822], skipping
# Room UUID: 10e405f3-5523-4722-96ad-36c3de799bc4
# Room 'Linde 102' already has correct occupants [3821], skipping
# Room UUID: d1903728-6171-4aec-a57b-0e3ff47b76f3
# Room 'Linde 113' already has correct occupants [3858, 3859], skipping
# Room UUID: 0946454f-dd93-4ca3-a096-962b2dff02ff
# Room 'Linde 116' already has correct occupants [3799], skipping
# Room UUID: d61de262-4def-4714-965b-31adb71c69f6
# Room 'Linde 129' already has correct occupants [3882], skipping
# Room UUID: aa8a87de-8b12-4462-b732-ebb8b968c2a0
# Room 'Linde 131' already has correct occupants [3800], skipping
# Room UUID: 3ef2a939-8987-45fe-ad56-553401177743
# Room 'Linde 201' already has correct occupants [3926], skipping
# Room UUID: f610b9d9-66b0-4c8c-a71d-28019dcbad55
# Room 'Linde 202' already has correct occupants [3798], skipping
# Room UUID: 65dfa875-2626-40c2-94b5-416fb51b6bbe
# Room 'Linde 207' already has correct occupants [3854, 3855], skipping
# Room UUID: cdee1bfc-2a78-4d3e-9260-9c89c378d212
# Room 'Linde 231' already has correct occupants [3824], skipping
# Room UUID: 00981475-ef4b-449c-9ad4-d59140c52560
# Room 'Linde 232' already has correct occupants [3823], skipping
# Room UUID: 09635151-3485-47e4-be39-2b2180e28c6b
# Room 'North 220' already has correct occupants [3764], skipping
# Room UUID: 9427e71b-fadd-46bc-b61b-6391639b0a25
# Room 'North 270' already has correct occupants [3763], skipping
# Room UUID: 2bfc2674-190c-4836-875c-c6eee4408c53
# Room 'North 272' already has correct occupants [3804], skipping
# Room UUID: ff1068fb-c726-40be-89b6-bf273783731a
# Room 'North 274' already has correct occupants [3829], skipping
# Room UUID: 22cc034d-6359-4c20-9e2b-f75b1e796d7d
# Room 'North 276' already has correct occupants [3803], skipping
# Room UUID: 3f0259ad-bca3-465a-b496-13a03f6b311f
# Room 'North 277' already has correct occupants [3888], skipping
# Room UUID: 7f80dfb5-c3c7-4406-bfa3-44f49e404c27
# Room 'Sontag 101A' already has correct occupants [3811], skipping
# Room UUID: 9703dba6-77e3-4214-939e-ff5cec05c864
# Room 'Sontag 101B' already has correct occupants [3812], skipping
# Room UUID: 7f3e1926-c938-4872-ae8e-9105c8dac647
# Room 'Sontag 103D' already has correct occupants [3775, 3776], skipping
# Room UUID: fa2bbe4e-c372-4eef-beeb-129cb43daa5b
# Room 'Sontag 105D' already has correct occupants [3923, 3924], skipping
# Room UUID: ef37b433-7311-4720-90ee-bf842b40f3b6
# Room 'Sontag 107A' already has correct occupants [3830], skipping
# Room UUID: 0a43f8c5-ef16-408a-9c2b-08c5a1e89223
# Room 'Sontag 107B' already has correct occupants [3892], skipping
# Room UUID: ea52bf51-db73-4da3-b2e6-032a747d2ae8
# Room 'Sontag 107C' already has correct occupants [3893], skipping
# Room UUID: ad07eaaf-b288-4885-a9e2-3ca28cc7393c
# Room 'Sontag 107D' already has correct occupants [3833, 3834], skipping
# Room UUID: 1b40d416-3d61-45fb-9eab-0bbd9f02af11
# Room 'Sontag 202A' already has correct occupants [3949], skipping
# Room UUID: d9d90b26-c219-4c8e-a785-2804e7d81753
# Room 'Sontag 202B' mismatch — DB: [], CSV: [3867, 3950]. Updating...
# Unexpected response clearing room 'Sontag 202B': 401 {"error":"Invalid token"}
# https://www.cs.hmc.edu/~elli/digitaldraw/api/rooms/preplace/d9d90b26-c219-4c8e-a785-2804e7d81753
# Response: 401
# Room UUID: d6a824dd-105b-4d27-82f1-4cbcff0f5e84
# Room 'Sontag 202C' already has correct occupants [3917], skipping
# Room UUID: 81e8a079-e96b-4f4b-9243-cf2c29f107cf
# Room 'Sontag 202D' already has correct occupants [3946, 3947], skipping
# Room UUID: c5d7ed89-87c9-43ef-a25e-998079ed0866
# Room 'Sontag 203A' already has correct occupants [3777], skipping
# Room UUID: 3ae782b4-a49a-4b05-873d-09f9556cad4e
# Room 'Sontag 204A' already has correct occupants [3951], skipping
# Room UUID: 71066737-0b1c-4184-ba63-8e13f8e40bcf
# Room 'Sontag 204B' already has correct occupants [3890], skipping
# Room UUID: f80bd9b9-a760-421d-afd3-307aaa05d201
# Room 'Sontag 204D' already has correct occupants [3847, 3848], skipping
# Room UUID: 57fca3b8-fe28-4467-abb7-fef46823e289
# Room 'Sontag 205D' already has correct occupants [3845, 3846], skipping
# Room UUID: b52c136c-7342-46c1-9e91-6daf155774f1
# Room 'Sontag 206A' already has correct occupants [3809], skipping
# Room UUID: 725c0c36-645e-482c-bf3d-66ffb409370d
# Room 'Sontag 206B' already has correct occupants [3810], skipping
# Room UUID: 571b27f0-24f3-4124-9367-537344eac6b2
# Room 'Sontag 207A' already has correct occupants [3774], skipping
# Room UUID: 03614dc4-3556-4186-b3eb-8673c39cf998
# Room 'Sontag 209A' already has correct occupants [3907], skipping
# Room UUID: d30499d9-1b2e-48a0-90e2-fb9d65709561
# Room 'Sontag 210A' already has correct occupants [3841], skipping
# Room UUID: 42787886-9d7b-41ac-9ea1-dfd5989c4b6e
# Room 'Sontag 210D' already has correct occupants [3839, 3840], skipping
# Room UUID: a91e157d-2b9e-4a2f-ae45-78706ccc2ebd
# Room 'South 301C' already has correct occupants [3802], skipping
# Room UUID: 0c46cd8c-ba3b-43dc-95d6-b12a95be365c
# Room 'South 301D' already has correct occupants [3801], skipping
# Room UUID: 54bdf919-7447-4744-b74c-29856f61d297
# Room 'South 304A' already has correct occupants [3761], skipping
# Room UUID: d89add9f-b8ed-4e6f-bdd1-25cf3fd3df3c
# Room 'South 304B' already has correct occupants [3762], skipping
# Room UUID: 4537fa61-3428-41a7-b898-b8b3a293a592
# Room 'South 304C' already has correct occupants [3870], skipping
# Room UUID: 362b472f-6cc3-4904-a421-876f00bea03a
# Room 'South 306A' already has correct occupants [3896], skipping
# Room UUID: 9f006916-fb8d-4ae3-8a34-e14ad3b3dc6f
# Room 'South 306B' already has correct occupants [3897], skipping
# Room UUID: 4417c2ce-af1f-4d2c-830a-a50afb27b493
# Room 'South 306C' already has correct occupants [3889], skipping
# Room UUID: baefde1e-b5bd-4104-9e86-7c14f9fa5b22
# Room 'South 309' already has correct occupants [3885], skipping
# Room UUID: da76e7cd-3c1b-40a8-98b0-3900095098b3
# Room 'South 310' already has correct occupants [3911], skipping
# Room UUID: 2f524e23-206b-4efa-8685-6dd691f1e773
# Room 'South 311' already has correct occupants [3838], skipping
# Room UUID: 16beb7c2-db39-4ebc-8695-d5f41c02337c
# Room 'South 351B' already has correct occupants [3952], skipping
# Room UUID: 84ffc8fa-758f-4483-8dc7-ed309db1fd41
# Room 'South 354A' already has correct occupants [3843], skipping
# Room UUID: 8cc66b34-5450-4c8d-a5fe-361a1d6cb9dc
# Room 'South 354B' already has correct occupants [3844], skipping
# Room UUID: 48a81487-9f8b-4bc8-a90e-042f7e2b2fa1
# Room 'South 355A' already has correct occupants [3887], skipping
# Room UUID: 1044062d-113d-49d4-8d5c-f495426cb621
# Room 'South 355B' already has correct occupants [3891], skipping
# Room UUID: 6710043f-5784-4286-a6ae-26e9003fc528
# Room 'South 356B' already has correct occupants [3877], skipping
# Room UUID: 3cf747d0-a094-43d0-9c1d-3fbd42631558
# Room 'South 356C' already has correct occupants [3760], skipping
# Room UUID: a58298f1-44e5-4fd6-99f7-471c55f82e77
# Room 'South 358A' already has correct occupants [3881], skipping
# Room UUID: 3158c27a-b0e2-4362-ae3c-590fc34a593a
# Room 'South 358B' already has correct occupants [3927], skipping
# Room UUID: 707ba416-ca61-467f-8dae-079c89dea81c
# Room 'South 358C' already has correct occupants [3933], skipping
# Room UUID: d3eba791-e0bd-446b-adb1-6e410e97791f
# Room 'South 360' already has correct occupants [3873], skipping
# Room UUID: 8b82c3ca-5dbf-4527-8b5d-28086d85182b
# Room 'West 420' already has correct occupants [3768], skipping
# Room UUID: b6423023-74ae-4f4c-b1fb-102966ac72a6
# Room 'West 421' already has correct occupants [3805], skipping
# Room UUID: 3dfe0a57-f811-45a5-ae40-8b8566c0d670
# Room 'West 425' already has correct occupants [3806], skipping
# Room UUID: f5664cbd-b23c-4c1d-9dc5-ab9599f3b6c0
# Room 'West 452' already has correct occupants [3765, 3766], skipping
# Room UUID: 5b584adb-fec5-4082-a926-1720db7de522
# Room 'West 469' already has correct occupants [3835], skipping
# Room UUID: 1cd4d121-b7d2-4bd3-a5d4-5bf37688b2f3
# Room 'West 470' already has correct occupants [3767], skipping
# Room UUID: 111e751d-dd02-4125-b1ec-5b4e07793631
# Room 'West 471' already has correct occupants [3884], skipping
# Room UUID: 45fe86d1-1398-4410-8072-932dc3470d19
# Room 'West 473' already has correct occupants [3769], skipping
# Room UUID: ff304515-88ad-483c-9418-2e7aad52ad05
# Room 'West 474' already has correct occupants [3875], skipping
