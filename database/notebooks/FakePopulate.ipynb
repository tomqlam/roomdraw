# %%
import requests
import random

# The URL of the endpoint you want to send a request to
base_url = 'https://www.cs.hmc.edu/~tlam/digitaldraw/api/'
jwt_token = "eyJhbGciOiJSUzI1NiIsImtpZCI6ImFkZjVlNzEwZWRmZWJlY2JlZmE5YTYxNDk1NjU0ZDAzYzBiOGVkZjgiLCJ0eXAiOiJKV1QifQ.....An6O0tacLv2R9vOR5l5fOXiH4bAFwUnH-N-3SDe4I6v-B9uqRRpsczPsaDuEF3gsUhOVu3PIOdxpwpaouLlSLY5tIHjen0Y5guSvpvaO-i6D2SHDhUTXvwhyfRxkSftPhfhR4xgNn-nTLyHXKUUiX6QZe4Y4OfAqypBMzaCkhlw-N_KqpxI3llCEUUn3vO9STp8MJeblxoOvIlSVDZDtKgXPQnsBmKgDjxQW3Y6toiozkzADmtqtjdauVBPI-M3GsykkC2ATx52d-OMQ5FORkdzRcFrtUWsbj7SDgdb3m-GulYb4eKJtXRLPh3GzSk0_3qhnJWl9FcGF4bVehCPEUw"
# Get users from /users
url = base_url + 'users'
# make sure to include auth headers with jwt token for every request
response = requests.get(url, headers={'Authorization': 'Bearer ' + jwt_token})
harvey_mudd_dorm_names = ['Atwood', 'Case', 'East', 'Linde', 'North', 'South', 'West', 'Sontag', 'Drinkward']

users = None
# Check the response
if response.status_code == 200:
    print('Successfully got users!')
    print(response.json())  # If response is in JSON format
    users = response.json()

# loop through list of users and remove all users that dont have a room uuid of 00000000-0000-0000-0000-000000000000
# this is because we only want to add users that don't have a room yet
for user in users:
    if user['RoomUUID'] != '00000000-0000-0000-0000-000000000000':
        users.remove(user)

if response.status_code == 404:
    print('Failed with status code:', response.status_code)
    exit(1)

# Get rooms from /rooms
url = base_url + 'rooms'
response = requests.get(url, headers={'Authorization': 'Bearer ' + jwt_token})
req_rooms = None

# Check the response
if response.status_code == 200:
    print('Successfully got rooms!')
    print(response.json())  # If response is in JSON format
    req_rooms = response.json()

if response.status_code == 404:
    print('Failed with status code:', response.status_code)
    exit(1)

dorms = {}

for dorm in harvey_mudd_dorm_names:
    dorms[dorm] = []
    url = base_url + 'rooms/simple/' + dorm
    response = requests.get(url, headers={'Authorization': 'Bearer ' + jwt_token})

    # Check the response
    if response.status_code == 200:
        print("Successfully got rooms for dorm " + dorm + "!")
        # print(response.json())
        dorms[dorm] = response.json()

    if response.status_code == 404:
        print('Failed with status code:', response.status_code)
        exit(1)

# in golang the structure of the dorm from simple route is as follows:
# type DormSimple struct {
# 	DormName    string        `json:"dormName"`
# 	Description string        `json:"description"`
# 	Floors      []FloorSimple `json:"floors"`
# }

# type FloorSimple struct {
# 	FloorNumber int           `json:"floorNumber"`
# 	Suites      []SuiteSimple `json:"suites"`
# }

# type SuiteSimple struct {
# 	Rooms       []RoomSimple `json:"rooms"`
# 	SuiteDesign string       `json:"suiteDesign"`
# 	SuiteUUID   uuid.UUID    `json:"suiteUUID"`
# }

# type RoomSimple struct {
# 	RoomNumber   string       `json:"roomNumber"`
# 	MaxOccupancy int          `json:"maxOccupancy"`
# 	PullPriority PullPriority `json:"pullPriority"`
# 	RoomUUID     uuid.UUID    `json:"roomUUID"`
# 	Occupant1    int          `json:"occupant1"`
# 	Occupant2    int          `json:"occupant2"`
# 	Occupant3    int          `json:"occupant3"`
# 	Occupant4    int          `json:"occupant4"`
# }
# data = {
    
# }

# # Send a POST request
# response = requests.post(url, json=data)

# # Send a GET request with parameters
# # response = requests.get(url, params=data)

# # Check the response
# if response.status_code == 200:
#     print('Success!')
#     print(response.json())  # If response is in JSON format
# else:
#     print('Failed with status code:', response.status_code)
# Out:
# Successfully got users!
# [{'Id': 4, 'Year': 'senior', 'FirstName': 'Hugh', 'LastName': 'Walker', 'Email': '', 'DrawNumber': 51, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 7, 'Year': 'senior', 'FirstName': 'Evelyn', 'LastName': 'Scott', 'Email': '', 'DrawNumber': 16, 'Preplaced': False, 'InDorm': 9, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 8, 'Year': 'senior', 'FirstName': 'Hasan', 'LastName': 'Kvamme', 'Email': '', 'DrawNumber': 97, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 10, 'Year': 'senior', 'FirstName': 'Ryan', 'LastName': 'Zhang', 'Email': '', 'DrawNumber': 172, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 12, 'Year': 'senior', 'FirstName': 'Jackie', 'LastName': 'Blankestijn', 'Email': '', 'DrawNumber': 109, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 14, 'Year': 'senior', 'FirstName': 'William', 'LastName': 'Brown', 'Email': '', 'DrawNumber': 23, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 16, 'Year': 'senior', 'FirstName': 'Viola', 'LastName': 'Schenkels', 'Email': '', 'DrawNumber': 91, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 18, 'Year': 'senior', 'FirstName': 'Musab', 'LastName': 'Kasbergen', 'Email': '', 'DrawNumber': 43, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 20, 'Year': 'senior', 'FirstName': 'Claudio', 'LastName': 'Garica', 'Email': '', 'DrawNumber': 198, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 24, 'Year': 'senior', 'FirstName': 'Juliette', 'LastName': 'Patel', 'Email': '', 'DrawNumber': 215, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 26, 'Year': 'senior', 'FirstName': 'Jagdish', 'LastName': 'Nayak', 'Email': '', 'DrawNumber': 29, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 30, 'Year': 'senior', 'FirstName': 'Dijana', 'LastName': 'Obradović', 'Email': '', 'DrawNumber': 10, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 32, 'Year': 'senior', 'FirstName': 'Amy', 'LastName': 'Lo', 'Email': '', 'DrawNumber': 72, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 36, 'Year': 'senior', 'FirstName': 'Brandon', 'LastName': 'Ryan', 'Email': '', 'DrawNumber': 42, 'Preplaced': False, 'InDorm': 0, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000-0000-000000000000'}, {'Id': 37, 'Year': 'senior', 'FirstName': 'Julia', 'LastName': 'Annala', 'Email': '', 'DrawNumber': 157, 'Preplaced': False, 'InDorm': 4, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'Participated': False, 'RoomUUID': '00000000-0000-0000- ...
# Successfully got rooms!
# [{'RoomUUID': '679eb71c-4c18-4785-a46d-f19dfc3f9b1c', 'Dorm': 1, 'DormName': 'East', 'RoomID': '103', 'SuiteUUID': '63fa4c3d-020a-4495-bed7-ac217946e2c6', 'MaxOccupancy': 2, 'CurrentOccupancy': 0, 'Occupants': None, 'PullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 1}, {'RoomUUID': 'e0267389-3610-47bb-b9c2-6b528b1af8b8', 'Dorm': 1, 'DormName': 'East', 'RoomID': '102', 'SuiteUUID': '831af151-8096-4358-b921-8aca56ddeaa7', 'MaxOccupancy': 2, 'CurrentOccupancy': 0, 'Occupants': None, 'PullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 2}, {'RoomUUID': 'e86b5155-7dad-4e47-a5dd-1747369ad5d6', 'Dorm': 1, 'DormName': 'East', 'RoomID': '104', 'SuiteUUID': '831af151-8096-4358-b921-8aca56ddeaa7', 'MaxOccupancy': 2, 'CurrentOccupancy': 0, 'Occupants': None, 'PullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 2}, {'RoomUUID': 'a4d3fcfa-8f10-497c-aabe-033b3f44055e', 'Dorm': 1, 'DormName': 'East', 'RoomID': '108', 'SuiteUUID': '03ba6f45-b895-4744-acfa-7d83ce884a62', 'MaxOccupancy': 2, 'CurrentOccupancy': 0, 'Occupants': None, 'PullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 2}, {'RoomUUID': '5712bf3e-39eb-4ade-85b8-decb8714b011', 'Dorm': 1, 'DormName': 'East', 'RoomID': '123', 'SuiteUUID': 'ec4ddec1-ed62-4db9-997c-5c405ee1088b', 'MaxOccupancy': 1, 'CurrentOccupancy': 0, 'Occupants': None, 'PullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 0}, {'RoomUUID': '7bfdd5a0-e30f-4bff-92c6-c6ee4ea0bf55', 'Dorm': 1, 'DormName': 'East', 'RoomID': '122', 'SuiteUUID': '51fea99f-6a0b-4648-8792-21383f1c5006', 'MaxOccupancy': 1, 'CurrentOccupancy': 0, 'Occupants': None, 'PullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 0}, {'RoomUUID': 'af88b47f-faec-45b2-8678-809262e4896c', 'Dorm': 1, 'DormName': 'East', 'RoomID': '109', 'SuiteUUID': 'f9fd3443-96fb-4686-aef9-6196424f7525', 'MaxOccupancy': 2, 'CurrentOccupancy': 1, 'Occupants': [691], 'PullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 198, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000-0000-000000000000', 'HasFrosh': False, 'FroshRoomType': 1}, {'RoomUUID': '7ee34010-86ba-4fe9-afdf-ee98785169f8', 'Dorm': 1, 'DormName': 'East', 'RoomID': '124', 'SuiteUUID': '7d3ea224-7fc0-4b4c-8275-8e4a266c1508', 'MaxOccupancy': 1, 'CurrentOccupancy': 1, 'Occupants': [114], 'PullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 67, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'SGroupUUID': '00000000-0000-0000- ...
# Successfully got rooms for dorm Atwood!
# Successfully got rooms for dorm Case!
# Successfully got rooms for dorm East!
# Successfully got rooms for dorm Linde!
# Successfully got rooms for dorm North!
# Successfully got rooms for dorm South!
# Successfully got rooms for dorm West!
# Successfully got rooms for dorm Sontag!
# Successfully got rooms for dorm Drinkward!

# %%
# print(dorms)
used_suites = {}
used_users = {}
# pick 3 random suites from each dorm
for i in range(10):
    for dormName in dorms:
        for floor in dorms[dormName]['floors']:
            dorm = dorms[dormName]
            print("Dorm: " + dormName)
            suite = random.choice(floor['suites'])
            print("Suite: " + str(suite))
            print("Suite UUID: " + suite['suiteUUID'])
            if suite['suiteUUID'] in used_suites:
                continue
            used_suites[suite['suiteUUID']] = True
            # pick a random room to be the suite leader
            try:
                room = random.choice(suite['rooms'])
            except:
                continue
        
            print("Leader Room: " + str(room))

            if room['maxOccupancy'] != 1:
                # pick some users and assign them to the room
                # pick a random number of users to assign to the room
                num_users = random.randint(1, room['maxOccupancy'])

                # pick random users to assign to the room
                # make sure the users are not already assigned to a room
                users_to_assign = []
                for j in range(num_users):
                    user = random.choice(users)
                    while user['Id'] in used_users:
                        user = random.choice(users)
                    used_users[user['Id']] = True
                    users_to_assign.append(user)
                
                # assign the users to the room with the following request body:
                # curl -X PATCH http:/localhost:8080/rooms/2c4a04bb-ddd6-4f02-ba55-a04aeb5d59f3 \
                #     -H "Content-Type: application/json" \
                #     -d '{"proposedOccupants": [9], "pullType": 1}'
                url = base_url + 'rooms/' + str(room['roomUUID'])
                data = {
                    "proposedOccupants": [user['Id'] for user in users_to_assign],
                    "pullType": 1
                }
                # response = requests.patch(url, json=data)
                response = requests.post(url, json=data, headers={'Authorization': 'Bearer ' + jwt_token})

                # Check the response
                if response.status_code == 200:
                    print('Successfully assigned users to room!')
                    print(response.json())
                else:
                    print('Failed with status code:', response.status_code)
            else:
                # pick a random user to assign to the room
                user = random.choice(users)
                while user['Id'] in used_users:
                    user = random.choice(users)
                used_users[user['Id']] = True

                # assign the user to the room with the following request body:
                # curl -X PATCH http:/localhost:8080/rooms/2c4a04bb-ddd6-4f02-ba55-a04aeb5d59f3 \
                #     -H "Content-Type: application/json" \
                #     -d '{"proposedOccupants": [9], "pullType": 1}'
                url = base_url + 'rooms/' + str(room['roomUUID'])
                data = {
                    "proposedOccupants": [user['Id']],
                    "pullType": 1
                }
                # response = requests.patch(url, json=data)
                response = requests.post(url, json=data, headers={'Authorization': 'Bearer ' + jwt_token})

                room_leader_uuid = room['roomUUID']

                # Check the response
                if response.status_code == 200:
                    print('Successfully assigned user to room!')
                    print(response.json())
                else:
                    print('Failed with status code:', response.status_code)
                
                try:
                    # pick a random room to be the suite leader
                    room = random.choice(suite['rooms'])
                except:
                    continue
                print("Pulled Room: " + str(room))

                if room['maxOccupancy'] != 1:
                    continue
                else:
                    # pick a random user to assign to the room
                    user = random.choice(users)
                    while user['Id'] in used_users:
                        user = random.choice(users)
                    used_users[user['Id']] = True

                    # assign the user to the room with the following request body:
                    # curl -X PATCH http:/localhost:8080/rooms/239f4ef3-052d-48fa-ac0f-a57900d87324 \
                    # -H "Content-Type: application/json" \
                    # -d '{"proposedOccupants": [8, 13, 14], "pullType": 2, "pullLeaderRoom": "2c4a04bb-ddd6-4f02-ba55-a04aeb5d59f3"}'
                    url = base_url + 'rooms/' + str(room['roomUUID'])
                    data = {
                        "proposedOccupants": [user['Id']],
                        "pullType": 2,
                        "pullLeaderRoom": room_leader_uuid
                    }
                    # response = requests.patch(url, json=data)
                    # add authheader containing the jwt token
                    response = requests.patch(url, json=data, headers={'Authorization': 'Bearer ' + jwt_token})
                    # response = requests.post(url, json=data)

                    # Check the response
                    if response.status_code == 200:
                        print('Successfully assigned user to room!')
                        print(response.json())
                    else:
                        print('Failed with status code:', response.status_code)
# Out:
# Dorm: Atwood
# Suite: {'rooms': [{'roomNumber': '325', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c00481c8-3049-4c1b-a7f3-0b48232c80c5', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '317', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '08c3116f-47c8-4f84-b6e3-b87167eb87e9', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '327', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '85bb487b-f4be-4ad5-9907-2d1cdafe9fa7', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}, {'roomNumber': '319', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'a2c8de33-66d9-48a3-8a07-01491ce2d8bd', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '321', 'maxOccupancy': 3, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c179bb7c-8f76-4811-8d19-2a6f52b92c7e', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 5}, {'roomNumber': '323', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 6, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '53051c75-6231-41fa-a31f-c55c680c89b3', 'occupant1': 19, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'dbfad9fd-4d60-461c-b1c6-7c8eed15cefe', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: dbfad9fd-4d60-461c-b1c6-7c8eed15cefe
# Leader Room: {'roomNumber': '321', 'maxOccupancy': 3, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c179bb7c-8f76-4811-8d19-2a6f52b92c7e', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 5}
# Failed with status code: 400
# Dorm: Atwood
# Suite: {'rooms': [{'roomNumber': '124', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '72c48179-2d54-447b-80d2-3efd2e8195a5', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '120', 'maxOccupancy': 3, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '0425d319-3045-4fea-bfa5-cb6063a2c3d5', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '126', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c9e7eabf-c38a-4f48-bc6e-ff2855952cb8', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 2}, {'roomNumber': '122', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '09306e6a-956d-4ad7-bbbd-c7289e2d9f17', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '116', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 46, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'e9e82175-746b-42aa-b2b1-218f36a78b73', 'occupant1': 564, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '118', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 3, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '37605394-3cfa-42aa-bb70-0aa93f409344', 'occupant1': 186, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '911c0d4c-adcd-45e0-89a1-5e5aaa56d803', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 911c0d4c-adcd-45e0-89a1-5e5aaa56d803
# Leader Room: {'roomNumber': '126', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c9e7eabf-c38a-4f48-bc6e-ff2855952cb8', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 2}
# Failed with status code: 400
# Dorm: Atwood
# Suite: {'rooms': [{'roomNumber': '218', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'cd33a301-1c26-4e16-836e-44a96458fde7', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '220', 'maxOccupancy': 3, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '465d93a7-b28b-4740-9301-964a9d95ad8f', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}, {'roomNumber': '226', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '31a0aab1-d09a-460d-bff4-8790f7d334c6', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '224', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'ce5184f5-0b08-4e8d-a985-99596275cbf7', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '222', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 171, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '35a67efa-eb71-4065-b304-6a78b078e8ab', 'occupant1': 568, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '216', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 55, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c2f89a61-9784-46ef-b0b7-099a41f755a1', 'occupant1': 171, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '519e0535-6cad-4483-81c7-3e3676fd600f', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 519e0535-6cad-4483-81c7-3e3676fd600f
# Leader Room: {'roomNumber': '218', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'cd33a301-1c26-4e16-836e-44a96458fde7', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '216', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 55, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c2f89a61-9784-46ef-b0b7-099a41f755a1', 'occupant1': 171, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: Case
# Suite: {'rooms': [{'roomNumber': '153', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c581efc4-8210-49ee-944a-c5a73eb00222', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}, {'roomNumber': '148', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'd75157ad-fb4c-401d-aa5b-3ceccb36e56a', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '154', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'dcc4c9e3-d333-4dd8-a7bf-7939ff88cdfb', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}, {'roomNumber': '151', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'ffdcb6ad-969c-4e8f-974a-0953af141c18', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '152', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '0ba0c4c8-7b79-482e-8dc0-15736f6208c6', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}, {'roomNumber': '149', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 210, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '4a4b3204-046d-4e4a-8d77-3578d07bfd7d', 'occupant1': 209, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '155', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 4, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '7ece8649-3176-4475-af01-603cdc72e66d', 'occupant1': 593, 'occupant2': 413, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 7}, {'roomNumber': '150', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 84, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'e52636ca-b715-4b9b-8d55-5c2eb503418b', 'occupant1': 102, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'bd1316a4-e1a0-4d30-923c-91c8fe442074', 'alternative_pull': True, 'can_lock_pull': False}
# Suite UUID: bd1316a4-e1a0-4d30-923c-91c8fe442074
# Leader Room: {'roomNumber': '153', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c581efc4-8210-49ee-944a-c5a73eb00222', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}
# Successfully assigned users to room!
# {'message': 'Successfully updated occupants'}
# Dorm: Case
# Suite: {'rooms': [{'roomNumber': 'Q2D', 'maxOccupancy': 4, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 77, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '7696c65a-4a35-40ad-817d-534e1d64e460', 'occupant1': 197, 'occupant2': 584, 'occupant3': 588, 'occupant4': 387, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '8e0bbef3-2549-47f8-bddf-c2d4c2d06a6c', 'alternative_pull': False, 'can_lock_pull': False}
# Suite UUID: 8e0bbef3-2549-47f8-bddf-c2d4c2d06a6c
# Leader Room: {'roomNumber': 'Q2D', 'maxOccupancy': 4, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 77, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '7696c65a-4a35-40ad-817d-534e1d64e460', 'occupant1': 197, 'occupant2': 584, 'occupant3': 588, 'occupant4': 387, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Dorm: East
# Suite: {'rooms': [{'roomNumber': '123', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '5712bf3e-39eb-4ade-85b8-decb8714b011', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '119', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 57, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '56aeaf9e-eb34-4d9b-9ffd-6e4b862d5217', 'occupant1': 426, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'ec4ddec1-ed62-4db9-997c-5c405ee1088b', 'alternative_pull': False, 'can_lock_pull': False}
# Suite UUID: ec4ddec1-ed62-4db9-997c-5c405ee1088b
# Leader Room: {'roomNumber': '119', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 57, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '56aeaf9e-eb34-4d9b-9ffd-6e4b862d5217', 'occupant1': 426, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '119', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 57, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '56aeaf9e-eb34-4d9b-9ffd-6e4b862d5217', 'occupant1': 426, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: East
# Suite: {'rooms': [{'roomNumber': '162', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '977095e2-eb0f-47d3-8d42-9ab8d435ba5c', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '160', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 94, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '7c2589f6-5fe8-447b-903c-9589d6c6e162', 'occupant1': 339, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}], 'suiteDesign': '', 'suiteUUID': 'a0826d26-f3a1-478d-b600-043e108fab5a', 'alternative_pull': True, 'can_lock_pull': False}
# Suite UUID: a0826d26-f3a1-478d-b600-043e108fab5a
# Leader Room: {'roomNumber': '160', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 94, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '7c2589f6-5fe8-447b-903c-9589d6c6e162', 'occupant1': 339, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}
# Failed with status code: 400
# Dorm: Linde
# Suite: {'rooms': [{'roomNumber': '141', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'e3372792-f166-45b9-b011-157dee0acda2', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '146', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '6687c631-e9e6-4f1a-bdd7-e478ad9b85b8', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '144', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 136, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '238d6f37-867d-4ee1-9106-fe199004ff0c', 'occupant1': 471, 'occupant2': 31, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '145', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 45, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'a929e640-76be-44b8-a8d2-e35415c8cbbb', 'occupant1': 38, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '84abcbb1-a166-4a61-a0d4-5bcbad11da09', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 84abcbb1-a166-4a61-a0d4-5bcbad11da09
# Leader Room: {'roomNumber': '146', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '6687c631-e9e6-4f1a-bdd7-e478ad9b85b8', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '144', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 136, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '238d6f37-867d-4ee1-9106-fe199004ff0c', 'occupant1': 471, 'occupant2': 31, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}
# Dorm: Linde
# Suite: {'rooms': [{'roomNumber': '247', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '967c2811-abc1-4d56-af8d-c98a236895cd', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '246', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '2a3e87b3-b527-4188-90de-878a32956fd6', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '244', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'dbeaa4b5-0f9c-41be-9cba-0ed075c3cb51', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '243', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 127, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '1b9ab61c-a9e7-4169-8fe1-48901ee52f9c', 'occupant1': 82, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}], 'suiteDesign': '', 'suiteUUID': 'f19d75dc-3455-49d3-8295-91457d697853', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: f19d75dc-3455-49d3-8295-91457d697853
# Leader Room: {'roomNumber': '247', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '967c2811-abc1-4d56-af8d-c98a236895cd', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '246', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '2a3e87b3-b527-4188-90de-878a32956fd6', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: North
# Suite: {'rooms': [{'roomNumber': '252', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 138, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '728c4d35-ed3e-4921-8472-7a81df874ebe', 'occupant1': 151, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '254', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 62, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'ea47d9b5-449a-472e-bfcf-765bc130fe23', 'occupant1': 91, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}], 'suiteDesign': '', 'suiteUUID': 'd03ee883-71dc-4c24-9d8b-448241cbdc21', 'alternative_pull': True, 'can_lock_pull': False}
# Suite UUID: d03ee883-71dc-4c24-9d8b-448241cbdc21
# Leader Room: {'roomNumber': '252', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 138, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '728c4d35-ed3e-4921-8472-7a81df874ebe', 'occupant1': 151, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}
# Failed with status code: 400
# Dorm: North
# Suite: {'rooms': [{'roomNumber': '220', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 85, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '5a0ab75b-68c7-48b3-8abd-c4e7a24b2ab5', 'occupant1': 191, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '224', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 95, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '3c63b95d-7f72-4274-a2e1-ca8d5e534655', 'occupant1': 264, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'a557f2b4-e304-446e-9ee7-20017aae1118', 'alternative_pull': False, 'can_lock_pull': False}
# Suite UUID: a557f2b4-e304-446e-9ee7-20017aae1118
# Leader Room: {'roomNumber': '224', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 95, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '3c63b95d-7f72-4274-a2e1-ca8d5e534655', 'occupant1': 264, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '220', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 85, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '5a0ab75b-68c7-48b3-8abd-c4e7a24b2ab5', 'occupant1': 191, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: South
# Suite: {'rooms': [{'roomNumber': '305A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '801d3577-b28f-4b85-935a-bd151a1278d9', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '305B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'b13b199e-d864-4a52-9ef7-94d1c0e9533e', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '305C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '2f27ba0d-0ff6-4257-894d-4e2c43e6d1b7', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}], 'suiteDesign': '', 'suiteUUID': '64103403-e49e-4f3c-8c8d-39aa3a075ef4', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 64103403-e49e-4f3c-8c8d-39aa3a075ef4
# Leader Room: {'roomNumber': '305C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '2f27ba0d-0ff6-4257-894d-4e2c43e6d1b7', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '305B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'b13b199e-d864-4a52-9ef7-94d1c0e9533e', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}
# Failed with status code: 403
# Dorm: South
# Suite: {'rooms': [{'roomNumber': '353A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '7bb4f178-f149-4579-b90d-16818134c42a', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}, {'roomNumber': '353C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '245c8baf-8f42-4c3e-8076-7936b98e9bf3', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}, {'roomNumber': '353B', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 168, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '720f8120-5a84-40bf-91b1-da25c0eeeec9', 'occupant1': 351, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}], 'suiteDesign': '', 'suiteUUID': 'a441f62c-9426-4451-819c-decb1adc7d0c', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: a441f62c-9426-4451-819c-decb1adc7d0c
# Leader Room: {'roomNumber': '353C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '245c8baf-8f42-4c3e-8076-7936b98e9bf3', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '353B', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 168, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '720f8120-5a84-40bf-91b1-da25c0eeeec9', 'occupant1': 351, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}
# Failed with status code: 403
# Dorm: West
# Suite: {'rooms': [{'roomNumber': '421', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '2b956e9b-2bf1-4234-9e91-fc8841788b55', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '425', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 217, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '9c184835-7de0-4fe8-b153-3444666dee20', 'occupant1': 302, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '8bc74bb9-bf5a-47ce-8a02-cebcfd5c4c4c', 'alternative_pull': False, 'can_lock_pull': False}
# Suite UUID: 8bc74bb9-bf5a-47ce-8a02-cebcfd5c4c4c
# Leader Room: {'roomNumber': '425', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 217, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '9c184835-7de0-4fe8-b153-3444666dee20', 'occupant1': 302, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '425', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 217, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '9c184835-7de0-4fe8-b153-3444666dee20', 'occupant1': 302, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: West
# Suite: {'rooms': [{'roomNumber': '454', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '55a11f2f-19c0-4502-8537-60cd4e510e15', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '452', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 142, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '3002fda0-332b-4263-9efa-c62840540783', 'occupant1': 104, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}], 'suiteDesign': '', 'suiteUUID': '9dc6d292-f9fd-4008-8c90-e1bac3cafde4', 'alternative_pull': True, 'can_lock_pull': False}
# Suite UUID: 9dc6d292-f9fd-4008-8c90-e1bac3cafde4
# Leader Room: {'roomNumber': '452', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 142, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '3002fda0-332b-4263-9efa-c62840540783', 'occupant1': 104, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}
# Failed with status code: 400
# Dorm: Sontag
# Suite: {'rooms': [{'roomNumber': '103A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '091c67eb-0df2-4dbb-8d82-ee465e3c3ad0', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '103D', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '10e9717f-adc7-49d9-a7c1-6e47227fd1e9', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '103C', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 113, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'b3f5cc89-b73b-47d4-915f-6ef08996ce8b', 'occupant1': 566, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '103B', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 143, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'e98dd765-bed3-4292-ba65-7af707aafb3a', 'occupant1': 2, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'a997209d-2d72-4438-bef8-de21f374c052', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: a997209d-2d72-4438-bef8-de21f374c052
# Leader Room: {'roomNumber': '103A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '091c67eb-0df2-4dbb-8d82-ee465e3c3ad0', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '103C', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 113, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'b3f5cc89-b73b-47d4-915f-6ef08996ce8b', 'occupant1': 566, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: Sontag
# Suite: {'rooms': [{'roomNumber': '210A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'cef72d19-5ad9-4e53-ba41-f6ad8409570c', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '210D', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'beb19615-8719-4a05-8254-ac7c0e4cf518', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 5}], 'suiteDesign': '', 'suiteUUID': 'e774abe1-6436-4226-9d87-3e22c569164a', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: e774abe1-6436-4226-9d87-3e22c569164a
# Leader Room: {'roomNumber': '210A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'cef72d19-5ad9-4e53-ba41-f6ad8409570c', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '210D', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'beb19615-8719-4a05-8254-ac7c0e4cf518', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 5}
# Dorm: Drinkward
# Suite: {'rooms': [{'roomNumber': '124C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 62, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '602fe568-7737-4927-a571-c0ee2a62e3ab', 'occupant1': 303, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 2}, {'roomNumber': '124D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 15, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '708124fc-00d5-470c-8bb9-b651d5acf998', 'occupant1': 72, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '124F', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 25, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'aabaac60-8e9d-4e40-8190-53febdd16fc4', 'occupant1': 165, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '124E', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 119, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '874ab471-189b-474d-bdb5-f65a8d67f123', 'occupant1': 345, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'bf2fbc7c-852b-4545-bff6-f39bf3cd314e', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: bf2fbc7c-852b-4545-bff6-f39bf3cd314e
# Leader Room: {'roomNumber': '124F', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 25, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'aabaac60-8e9d-4e40-8190-53febdd16fc4', 'occupant1': 165, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Pulled Room: {'roomNumber': '124F', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 25, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'aabaac60-8e9d-4e40-8190-53febdd16fc4', 'occupant1': 165, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: Drinkward
# Suite: {'rooms': [{'roomNumber': '222E', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'bba75cf2-0d6d-4d5b-8874-1d660131e50c', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '222D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 14, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '16dad349-d60e-4392-a220-ac438cf9292b', 'occupant1': 306, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '222C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 213, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'dd524cd7-61f1-4e81-824d-e665b7d9fc5f', 'occupant1': 126, 'occupant2': 602, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'eb389ac9-0304-4eb7-97b2-ff84bb311847', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: eb389ac9-0304-4eb7-97b2-ff84bb311847
# Leader Room: {'roomNumber': '222C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 213, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'dd524cd7-61f1-4e81-824d-e665b7d9fc5f', 'occupant1': 126, 'occupant2': 602, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 400
# Dorm: Drinkward
# Suite: {'rooms': [{'roomNumber': '323F', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '4240ac4d-e06b-4f9c-ae24-3362dff84bc8', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '323D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 184, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c48b72c5-9878-421d-9600-9a33c7a15cd6', 'occupant1': 66, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '323C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': True, 'drawNumber': 175, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '296f9ee0-e56f-4031-b202-59dd9e3b7918', 'occupant1': 195, 'occupant2': 606, 'occupant3': 103, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}, {'roomNumber': '323E', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 213, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '4696ad98-43c3-44d3-abf3-881f167e167f', 'occupant1': 436, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '0d4f5f8e-56c9-409d-ab8e-10dd14cb31a2', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 0d4f5f8e-56c9-409d-ab8e-10dd14cb31a2
# Leader Room: {'roomNumber': '323C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': True, 'drawNumber': 175, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '296f9ee0-e56f-4031-b202-59dd9e3b7918', 'occupant1': 195, 'occupant2': 606, 'occupant3': 103, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 6}
# Failed with status code: 400
# Dorm: Atwood
# ...
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '228', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 11, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'c8f89bd6-1cf2-42f0-a457-73c05f397de8', 'occupant1': 53, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: South
# Suite: {'rooms': [{'roomNumber': '302B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'd596f2a6-3c48-4939-8e04-d0e95cf23664', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '302A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'b35b5461-42a8-4c36-a028-939d4f39637c', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '302C', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 207, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'a17494ab-6426-457a-a4f3-50cb817ab420', 'occupant1': 444, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '302D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 151, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '68c8994a-3d1a-4519-ac2a-6b8375bf69cc', 'occupant1': 172, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '6d040436-58c9-40af-bbfa-0f3955a5fda4', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 6d040436-58c9-40af-bbfa-0f3955a5fda4
# Leader Room: {'roomNumber': '302B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'd596f2a6-3c48-4939-8e04-d0e95cf23664', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '302B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'd596f2a6-3c48-4939-8e04-d0e95cf23664', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}
# Failed with status code: 403
# Dorm: South
# Suite: {'rooms': [{'roomNumber': '354C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '293c49ca-85cc-44f9-bb66-eb0a7642bbc2', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '354B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '0a565a56-7c25-4fd9-886d-99c92efb3cf6', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '354A', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 193, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'bf961a1b-1341-4824-9dd7-c3e6850df72a', 'occupant1': 476, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}], 'suiteDesign': '', 'suiteUUID': 'c18045bb-f801-4646-8beb-8374d65ca06d', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: c18045bb-f801-4646-8beb-8374d65ca06d
# Leader Room: {'roomNumber': '354B', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '0a565a56-7c25-4fd9-886d-99c92efb3cf6', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}
# Successfully assigned user to room!
# {'message': 'Successfully updated occupants'}
# Pulled Room: {'roomNumber': '354C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '293c49ca-85cc-44f9-bb66-eb0a7642bbc2', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}
# Failed with status code: 403
# Dorm: West
# Suite: {'rooms': [{'roomNumber': '405', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'ab0351fb-2ac3-4d6f-8102-606421502692', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '407', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 155, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'd8f53d5f-6ad3-4b85-97ac-148903b6a001', 'occupant1': 488, 'occupant2': 130, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}], 'suiteDesign': '', 'suiteUUID': 'eb801078-56eb-4642-bad0-119197fda40c', 'alternative_pull': True, 'can_lock_pull': False}
# Suite UUID: eb801078-56eb-4642-bad0-119197fda40c
# Dorm: West
# Suite: {'rooms': [{'roomNumber': '457', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 9, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '498bf067-24d1-4427-ade5-de89edc3afae', 'occupant1': 377, 'occupant2': 292, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}, {'roomNumber': '455', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 166, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '6a4484f6-190c-4bfa-949e-6234aad826f5', 'occupant1': 460, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 3}], 'suiteDesign': '', 'suiteUUID': '1a7bbce5-6bf4-451f-b7c7-cc9e08f46c12', 'alternative_pull': True, 'can_lock_pull': False}
# Suite UUID: 1a7bbce5-6bf4-451f-b7c7-cc9e08f46c12
# Dorm: Sontag
# Suite: {'rooms': [{'roomNumber': '106C', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '4b0ff6db-2b62-4530-aee0-4f35e7971c82', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '106D', 'maxOccupancy': 2, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '58396af2-4ce2-4c46-bd02-b7b859b90f8f', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 1}, {'roomNumber': '106A', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 176, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '053673a7-6398-4e7b-a2a7-807d6d17bddd', 'occupant1': 164, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '106B', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 145, 'year': 2, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '2c1460ad-fd52-4ef1-8938-31944bd8c8f7', 'occupant1': 489, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'd397ab17-61f1-4230-81fc-5403b27c5683', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: d397ab17-61f1-4230-81fc-5403b27c5683
# Dorm: Sontag
# Suite: {'rooms': [{'roomNumber': '204A', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '9cdf2efd-7f9b-4359-9b9b-a29477a1ae82', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '204B', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 123, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '97ffc306-bc8b-4ce2-a948-df0deaf4d1c5', 'occupant1': 1, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '204D', 'maxOccupancy': 2, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': True, 'drawNumber': 47, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '240551cd-027c-4a84-89b9-70a3b1a5ea8d', 'occupant1': 5, 'occupant2': 647, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}], 'suiteDesign': '', 'suiteUUID': 'c25aba7a-a511-429c-a33e-473944348425', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: c25aba7a-a511-429c-a33e-473944348425
# Dorm: Drinkward
# Suite: {'rooms': [{'roomNumber': '124C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 62, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '602fe568-7737-4927-a571-c0ee2a62e3ab', 'occupant1': 303, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 2}, {'roomNumber': '124D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 15, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '708124fc-00d5-470c-8bb9-b651d5acf998', 'occupant1': 72, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '124F', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 25, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'aabaac60-8e9d-4e40-8190-53febdd16fc4', 'occupant1': 165, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '124E', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 119, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '874ab471-189b-474d-bdb5-f65a8d67f123', 'occupant1': 345, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': 'bf2fbc7c-852b-4545-bff6-f39bf3cd314e', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: bf2fbc7c-852b-4545-bff6-f39bf3cd314e
# Dorm: Drinkward
# Suite: {'rooms': [{'roomNumber': '223C', 'maxOccupancy': 3, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '008c392c-2c1f-4044-9e08-e723c36a64f9', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 4}, {'roomNumber': '223F', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 226, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'd82c1715-4b73-4b8e-8229-3c4e9345c6c1', 'occupant1': 25, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '223D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 125, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': 'ecf4218c-11e9-419a-adde-16e530a13e7c', 'occupant1': 395, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '223E', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 67, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '1e54e0b1-f403-445c-aeec-5fdef20ba0b7', 'occupant1': 408, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '9aac743f-3e35-4d09-a148-5dc5d748e6e7', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 9aac743f-3e35-4d09-a148-5dc5d748e6e7
# Dorm: Drinkward
# Suite: {'rooms': [{'roomNumber': '322E', 'maxOccupancy': 1, 'pullPriority': {'valid': False, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0, 'pullType': 0, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '04cea54e-2e74-40e1-96d9-6170b61e125d', 'occupant1': 0, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '322C', 'maxOccupancy': 3, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': True, 'drawNumber': 208, 'year': 4, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '6443c3e5-4f11-4310-b644-0886e6fc76cf', 'occupant1': 77, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}, {'roomNumber': '322D', 'maxOccupancy': 1, 'pullPriority': {'valid': True, 'isPreplaced': False, 'hasInDorm': False, 'drawNumber': 160, 'year': 3, 'pullType': 1, 'inherited': {'valid': False, 'hasInDorm': False, 'drawNumber': 0, 'year': 0}}, 'roomUUID': '804d2949-f971-4ae6-b43b-c5315cdc1157', 'occupant1': 291, 'occupant2': 0, 'occupant3': 0, 'occupant4': 0, 'hasFrosh': False, 'froshRoomType': 0}], 'suiteDesign': '', 'suiteUUID': '55f715f6-a628-436d-ae43-68b36a1d8fb1', 'alternative_pull': False, 'can_lock_pull': True}
# Suite UUID: 55f715f6-a628-436d-ae43-68b36a1d8fb1
