# %%
# read in preplacements.csv into a dataframe

import pandas as pd
import numpy as np

df = pd.read_csv('preplacements.csv')


# Dorm Mapping
# 1 = East
# 2 = North
# 3 = South
# 4 = West
# 5 = Atwood
# 6 = Sontag
# 7 = Case
# 8 = Drinkward
# 9 = Linde
dorm_mapping = {
    'East': 1,
    'North': 2,
    'South': 3,
    'West': 4,
    'Atwood': 5,
    'Sontag': 6,
    'Case': 7,
    'Drinkward': 8,
    'Linde': 9,
    'Garrett House': 10
}

# remove any rows that don't have email, Dorm, or Room
df = df[df['Email'].notna() & df['Dorm'].notna() & df['Room'].notna()]

# remove any uppercase letters
df['Email'] = df['Email'].str.lower()
# if email ends in @hmc.edu, replace with @g.hmc.edu
df['Email'] = df['Email'].str.replace('@hmc.edu', '@g.hmc.edu')

# print the first 5 rows of the dataframe

# strip any whitespace from first name and last name and email and dorm and room
df['First Name'] = df['First Name'].str.strip()
df['Last Name'] = df['Last Name'].str.strip()
df['Email'] = df['Email'].str.strip()
df['Dorm'] = df['Dorm'].str.strip()
df['Room'] = df['Room'].str.strip()

# remove any rows that are not in the dorm mapping
df = df[df['Dorm'].isin(dorm_mapping.keys())]

print(df)
# Out:
#              ID First Name   Last Name                  Email    Dorm Room
# 0    40210325.0      Ethan     Vazquez     evazquez@g.hmc.edu  Atwood  110
# 1    40224654.0      Livia     Ordonez     lordonez@g.hmc.edu  Atwood  114
# 2    40224478.0      Anika      Pandey     anpandey@g.hmc.edu  Atwood  114
# 3    40213260.0      Arman      Khasru      akhasru@g.hmc.edu  Atwood  123
# 4    40217298.0     Edward      Donson      edonson@g.hmc.edu  Atwood  125
# ..          ...        ...         ...                    ...     ...  ...
# 226  40221969.0   Adrianne        Baik        abaik@g.hmc.edu    West  423
# 227  40217934.0    McKenna    McMurray    mmcmurray@g.hmc.edu    West  471
# 228  40223717.0       Emmy       Hoorn       ehoorn@g.hmc.edu    West  473
# 229  40215698.0      Diane        Park       dipark@g.hmc.edu    West  475
# 230  40221268.0       Adam  Vanluvanee  avanluvanee@g.hmc.edu   Linde  144
#
# [223 rows x 6 columns]

# %%
from sqlalchemy import create_engine
from sqlalchemy.sql import text

# import env variables
import os
from dotenv import load_dotenv
from pathlib import Path

# import libraries for ssh tunneling
import sshtunnel

dotenv_path = os.path.join(os.getcwd(), '.env')
print(dotenv_path)

load_dotenv(dotenv_path=dotenv_path, verbose=True)

sql_pass = os.environ.get('SQL_PASS')
sql_ip = os.environ.get('SQL_IP')
sql_db_name = os.environ.get('SQL_DB_NAME')
sql_user = os.environ.get('SQL_USER')

tunnel_host = os.environ.get('TUNNEL_HOST')
tunnel_port = os.environ.get('TUNNEL_PORT')
tunnel_user = os.environ.get('TUNNEL_USER')
tunnel_pass = os.environ.get('TUNNEL_PASS')

tunnel = sshtunnel.SSHTunnelForwarder(
    (tunnel_host, int(tunnel_port)),
    ssh_username=tunnel_user,
    ssh_password=tunnel_pass,
    remote_bind_address=(sql_ip, 5432)
)

# After starting the tunnel
tunnel.start()

# Get the local bind port that the tunnel is using
local_port = tunnel.local_bind_port

# Update connection string to use localhost and the tunneled port
CONNSTR = f'postgresql://{sql_user}:{sql_pass}@127.0.0.1:{local_port}/{sql_db_name}'

# Now create your SQLAlchemy engine with this connection string
engine = create_engine(CONNSTR)

# Test the connection
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print("Connection successful!")
# Out:
# /home/tomql/workspaces/roomdraw/database/.env
# Connection successful!

# %%
import requests
selection = input("Do you want to preplace in development or production? (dev/prod) ")
base_url = "http://localhost:8080/rooms/preplace/"
if selection != "dev" and selection != "prod":
    print("Invalid selection, please try again")
    exit()

if selection == "dev":
    base_url = "http://localhost:8080/rooms/preplace/"
else:
    base_url = "https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/"

admin_jwt = input("Please enter your admin JWT: ")

# link is localhost:8080/rooms/preplace/:roomuuid
# query the database to get all the rooms

# mapping of email to user id in the database
preplaced_user_ids = {}
room_ids = {}
with engine.connect() as connection:
    query = "SELECT room_uuid, dorm_name, room_id FROM rooms"
    result = connection.execute(text(query))
    # create a dictionary to store the room ids
    
    # loop through the result and add the room ids to the dictionary
    for row in result:
        room_ids[f'{row[1]} {row[2]}'] = row[0]
    query = "SELECT email, id FROM users WHERE preplaced = True"
    result = connection.execute(text(query))
    for row in result:
        preplaced_user_ids[row[0]] = row[1]
    connection.commit()
    
print(preplaced_user_ids)
print(room_ids)

# find all rows where the which share a common value for both Dorm and Room
# iterate through the groups that share a common value for both Dorm and Room and print the group
for name, group in df.groupby(['Dorm', 'Room']):
    if "Garrett House" in name:
        continue
    # find the room_uuid for the group
    room_uuid = room_ids[f'{name[0]} {name[1]}']
    print(f'Room UUID: {room_uuid}')

    # create a rest call to the server to preplace the users in the group
    # rest request body contains json with:
    # type PreplacedRequest struct {
    # 	ProposedOccupants []int  `json:"proposedOccupants"`
    # 	UserJWT           string `json:"userJWT"`
    # }
    # use the id of the users in the group to create the proposed occupants list
    users_in_group = group['Email'].tolist()
    print(users_in_group)
    # convert the emails to user ids
    proposed_occupants = [preplaced_user_ids[email] for email in users_in_group]

    json_body = {
        'proposedOccupants': proposed_occupants,
        'userJWT': admin_jwt
    }

    # create the headers for the rest request
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {admin_jwt}'
    }

    # create the url for the rest request
    url = f'{base_url}{room_uuid}'

    print(url)

    response = requests.post(url, headers=headers, json=json_body)

    # print the response
    # print(response.json())
# Out:
# {'evazquez@g.hmc.edu': 477, 'lordonez@g.hmc.edu': 478, 'anpandey@g.hmc.edu': 479, 'akhasru@g.hmc.edu': 480, 'edonson@g.hmc.edu': 481, 'mabuchanan@g.hmc.edu': 482, 'olhubert@g.hmc.edu': 483, 'aprucnal@g.hmc.edu': 484, 'sqiu@g.hmc.edu': 485, 'acary@g.hmc.edu': 486, 'manortiz@g.hmc.edu': 487, 'larwang@g.hmc.edu': 488, 'tixie@g.hmc.edu': 489, 'allbarker@g.hmc.edu': 490, 'akit
 112': UUID('bf13a984-749e-4b03-b5fd-45ef17b89529'), 'East 110': UUID('d73b087e-0ed7-4942-a7d8-6f4f9bdb0ef9'), 'East 115': UUID('2c15a038-6b8d-46f8-9442-f9d50a3bc2dc'), 'East 113': UUID('63471564-784d-4669-972f-7195f451de34'), 'East 114': UUID('67f7c448-d354-4db2-a14f-0f8e7a189a27'), 'East 116': UUID('78de6f55-80f1-4c77-8173-555730d5ea6e'), 'East 119': UUID('adf516d1-2046-4d4b-8e62-607f527bfed6'), 'East 123': UUID('62d35552-6f39-40fd-8d4b-0636f1f98883'), 'East 124': UUID('1bad0046-cb98-4d93-a48e-5ceba04d8965'), 'East 120': UUID('9bf53d53-916b-4e42-8b2f-1b4b019f44cd'), 'East 121': UUID('612c36fa-8dba-461a-b80d-1a387bce223a'), 'East 125': UUID('fc805fb3-5aa2-4428-a4b2-6cba88670e8a'), 'East 126': UUID('80116283-7007-49d4-915d-9667296db258'), 'East 122': UUID('53e5bd5f-13a4-42a7-bb5a-1273fee6b402'), 'East 127': UUID('76597634-2738-4158-aece-c56412cda5ce'), 'East 128': UUID('1e6048a5-a25e-439a-8ec2-dd40826b27e3'), 'East 151': UUID('656ed392-49d9-4571-b0b1-94f04d2c228f'), 'East 153': UUID('89b587e2-d633-41a6-a59a-3ad1936c0b0a'), 'East 154': UUID('e1dbbc07-e03b-4a51-925b-faed1409dafd'), 'East 152': UUID('982491e4-542e-4567-bf31-5105e5efc5c4'), 'East 155': UUID('f983e45c-7964-486d-8a6d-a5986169520a'), 'East 157': UUID('2346e7ef-53fe-4938-a1f5-3a822fdfcf49'), 'East 156': UUID('e1f0d2f5-bb04-4842-a5c9-1b26b40f42a2'), 'East 158': UUID('068eb08a-0c8e-49c1-a16d-3f56998e6a07'), 'East 159': UUID('52237ecf-8f75-4ee7-bc10-d80a411e6488'), 'East 161': UUID('54a21a39-87ee-41b6-afd0-244da7100ed4'), 'East 160': UUID('50fde070-14ad-44b9-8e4c-eb685ffe3f7b'), 'East 162': UUID('b99e3fd1-5ab2-4944-a139-9694ce0df639'), 'East 165': UUID('40af1b4a-5b0e-4803-a5a0-5a4b3e7d04b2'), 'East 163': UUID('376b1095-ce22-49bb-ab79-6f9300d4cabe'), 'East 166': UUID('d63cab96-9f7b-47fe-8f3c-c19c372520be'), 'East 164': UUID('4270339b-80c2-43df-b185-f4ce8226f303'), 'East 169': UUID('6cb781b9-e448-475d-8872-12c906c2beea'), 'East 173': UUID('f2617222-70da-4988-8f89-d80a50d5917f'), 'East 174': UUID('e96e5965-b384-45e1-af5a-1d9ea384b487'), 'East 170': UUID('aaf9662e-1fa2-4487-9156-3521ab8bd3e2'), 'East 175': UUID('f66cff81-7eff-48a8-b361-c8ec3849d9f5'), 'East 171': UUID('eb73efdb-367a-4118-a576-5d874421db79'), 'East 176': UUID('a144a3dc-3586-447b-a0eb-ad1e7868f815'), 'East 172': UUID('c584f4ee-ae11-4b5f-b6f3-a416810511e2'), 'East 177': UUID('03caf419-ee61-4c6f-8903-34177b205a49'), 'East 178': UUID('4895b52c-f2f2-4486-ac3e-ab816846f444'), 'North 201': UUID('6bbeb69b-84b5-4e95-aaed-5f3abb6b88ce'), 'North 203': UUID('1d40ff7f-191c-40cc-8e14-46a235c45511'), 'North 204': UUID('ed583e39-44e4-4b5a-b617-a2a5e5dcbb4d'), 'North 202': UUID('fc35e4f4-5a32-4d2a-9bf4-43bfe8eaf899'), 'North 207': UUID('37ee4ad9-f3e9-4aa7-8dd2-668acf392888'), 'North 205': UUID('5931bf01-0a3d-4aeb-a167-3f10b582aec2'), 'North 208': UUID('f09e3ee8-1e87-461c-bc4c-bff9a4b364c1'), 'North 206': UUID('77c3f333-71c4-444c-8722-f2bf02be754b'), 'North 211': UUID('229effcf-4d07-4324-915c-d81fb10ea5e6'), 'North 209': UUID('2c790235-9b93-4823-bf09-9aba777603e4'), 'North 212': UUID('5fb164cc-fa7f-4bac-b4a8-2bdeaef89183'), 'North 210': UUID('5226c48c-7a86-4b7f-868b-4b82443058f0'), 'North 213': UUID('a6c12832-3e6e-430f-b73b-7f64cea4e1ad'), 'North 215': UUID('1ec374ea-7563-44a7-a09e-0f91a9c772cd'), 'North 214': UUID('3aaed592-f8f3-4463-aff0-2c9f55911806'), 'North 216': UUID('93df9880-f354-49b5-8780-95dc23a82c39'), 'North 223': UUID('449b0849-0708-442b-8 ...
# Room UUID: 3530c686-79d1-4028-85a3-721faf848868
# ['zacollins@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/3530c686-79d1-4028-85a3-721faf848868
# Room UUID: 19bff0e5-635e-432e-9277-ba5e1c78138e
# ['emlo@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/19bff0e5-635e-432e-9277-ba5e1c78138e
# Room UUID: 234200b3-ab09-41a2-96e8-64e211f6a065
# ['evazquez@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/234200b3-ab09-41a2-96e8-64e211f6a065
# Room UUID: 33420ae1-c28b-4e89-be3a-61414634a1d6
# ['soflores@g.hmc.edu', 'katlam@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/33420ae1-c28b-4e89-be3a-61414634a1d6
# Room UUID: 5d09f341-1811-465a-bad9-961a7f476a7b
# ['lordonez@g.hmc.edu', 'anpandey@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/5d09f341-1811-465a-bad9-961a7f476a7b
# Room UUID: 67a6aa2d-deb7-4196-9328-5ec5e56f74b8
# ['akhasru@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/67a6aa2d-deb7-4196-9328-5ec5e56f74b8
# Room UUID: 66fb8c15-032b-4b24-bf5b-62eb4a091c08
# ['edonson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/66fb8c15-032b-4b24-bf5b-62eb4a091c08
# Room UUID: 4f582e24-8814-4fe7-b8d2-61d2b9e7862d
# ['allbarker@g.hmc.edu', 'akitrell@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/4f582e24-8814-4fe7-b8d2-61d2b9e7862d
# Room UUID: 853d9aae-9e06-48ab-bf44-f20db6d2c839
# ['mabuchanan@g.hmc.edu', 'olhubert@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/853d9aae-9e06-48ab-bf44-f20db6d2c839
# Room UUID: 8bcde067-9e1c-46ef-a791-d1da858c6ec1
# ['aprucnal@g.hmc.edu', 'sqiu@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace
g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/0f1272c5-bc28-4ebf-a63c-8aca466779b8
# Room UUID: 0f2f5e6f-f4ae-4b2f-815f-8612234aeed0
# ['andwilliams@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/0f2f5e6f-f4ae-4b2f-815f-8612234aeed0
# Room UUID: 1db3c44f-c60a-49f8-baa8-24dd17a3785a
# ['alrosenberg@g.hmc.edu', 'tyoo@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/1db3c44f-c60a-49f8-baa8-24dd17a3785a
# Room UUID: b7f877a7-562a-476f-a076-96cfb8a6c738
# ['oheraigarrison@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/b7f877a7-562a-476f-a076-96cfb8a6c738
# Room UUID: cdf10220-bd05-485c-b30e-c741cdd27a52
# ['wzheng@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/cdf10220-bd05-485c-b30e-c741cdd27a52
# Room UUID: f6c9393b-de30-4679-85c0-02a1eafa79c4
# ['narce@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f6c9393b-de30-4679-85c0-02a1eafa79c4
# Room UUID: f2b7f983-5244-4f4d-9d8a-bf270509e658
# ['greynolds@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f2b7f983-5244-4f4d-9d8a-bf270509e658
# Room UUID: 9fb5fa4c-8c2e-49ff-9164-35b2ecc2cc69
# ['mdavi@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/9fb5fa4c-8c2e-49ff-9164-35b2ecc2cc69
# Room UUID: e4986b45-00b2-4b8d-8cf9-7611216de1b9
# ['jsesate@g.hmc.edu', 'sojayaweera@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e4986b45-00b2-4b8d-8cf9-7611216de1b9
# Room UUID: c6dffdcf-9d4b-459f-a328-3bb8d368d888
# ['mibryan@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/c6dffdcf-9d4b-459f-a328-3bb8d368d888
# Room UUID: e2b210d4-1591-4003-a823-84ea9e565180
# ['jheinstein@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e2b210d4-1591-4003-a823-84ea9e565180
# Room UUID: d31ba115-a37b-4543-a678-ede095d5edbf
# ['smichaelson@g.hmc.edu', 'ltu@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d31ba115-a37b-4543-a678-ede095d5edbf
# Room UUID: 7b58c1c1-48b2-4edb-b5fb-41332145ad46
# ['tbaugh@g.hmc.edu', 'tghai@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/7b58c1c1-48b2-4edb-b5fb-41332145ad46
# Room UUID: 7ee955f0-729d-4de1-ab04-a72b9c63a54e
# ['bogao@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/7ee955f0-729d-4de1-ab04-a72b9c63a54e
# Room UUID: dca4672a-c4cd-4ecf-82a3-e0dc7137d5af
# ['lilzhu@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/dca4672a-c4cd-4ecf-82a3-e0dc7137d5af
# Room UUID: d1f6d69b-b81b-4be9-a36d-1dd8ec5d3178
# ['klopez@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d1f6d69b-b81b-4be9-a36d-1dd8ec5d3178
# Room UUID: 37a63cab-86ea-41e5-9a5b-bf10781b3c6a
# ['yye@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/37a63cab-86ea-41e5-9a5b-bf10781b3c6a
# Room UUID: 9af46f52-6c5d-4490-b71a-b4ecf66bc2a9
# ['afigge@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/9af46f52-6c5d-4490-b71a-b4ecf66bc2a9
# Room UUID: 1e1df440-24ac-43b0-9890-1dc1ab741378
# ['jadwong@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/1e1df440-24ac-43b0-9890-1dc1ab741378
# Room UUID: 156df5b6-50ea-43c4-96a3-2b275ab5a3c5
# ['iswart@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/156df5b6-50ea-43c4-96a3-2b275ab5a3c5
# Room UUID: 15c8a514-dda3-4f33-95d0-f964400b33d7
# ['pragupta@g.hmc.edu', 'rwandeler@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/15c8a514-dda3-4f33-95d0-f964400b33d7
# Room UUID: efee1948-4c47-40bc-a6db-5dc50dd499d0
# ['skoneru@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/efee1948-4c47-40bc-a6db-5dc50dd499d0
# Room UUID: 6d011ea8-c7eb-4ece-a673-fe3c3a39c5f5
# ['atidmarsh@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/6d011ea8-c7eb-4ece-a673-fe3c3a39c5f5
# Room UUID: 2e080b7f-e806-4fa3-910a-d4a4a10d0eb2
# ['asawyer@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/2e080b7f-e806-4fa3-910a-d4a4a10d0eb2
# Room UUID: 45cc55d7-a56c-4267-b648-cf791d2d25b4
# ['candrieuxamadei@g.hmc.edu', 'kacheng@g.hmc.edu', 'akimdon@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/45cc55d7-a56c-4267-b648-cf791d2d25b4
# Room UUID: d66325c3-6abf-4cce-856c-430ee6a8c67b
# ['fmourelatos@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d66325c3-6abf-4cce-856c-430ee6a8c67b
# Room UUID: b1b707c4-7feb-48c7-83a3-5dfa48727fb6
# ['simyang@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/b1b707c4-7feb-48c7-83a3-5dfa48727fb6
# Room UUID: ef2cddda-03e3-420a-8dba-36dffdf1b9d0
# ['jluu@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/ef2cddda-03e3-420a-8dba-36dffdf1b9d0
# Room UUID: c7193643-11de-4dff-a30b-60453e4afc15
# ['lumorgan@g.hmc.edu', 'bsimpson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/c7193643-11de-4dff-a30b-60453e4afc15
# Room UUID: 556745aa-f08a-4b56-acda-bc224a15f694
# ['hrepp@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/556745aa-f08a-4b56-acda-bc224a15f694
# Room UUID: 552bdbdb-0cf3-40e3-8da4-b7aef7ee5855
# ['arock@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/552bdbdb-0cf3-40e3-8da4-b7aef7ee5855
# Room UUID: b3dd1517-c358-43f3-ad07-a470ae85ccf2
# ['lukewang@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/b3dd1517-c358-43f3-ad07-a470ae85ccf2
# Room UUID: 2652b244-6a53-48d0-a6e5-33149ac15836
# ['cadawson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/2652b244-6a53-48d0-a6e5-33149ac15836
# Room UUID: 7a6cc325-e50f-42d5-96ca-b223593a43e6
# ['gwickham@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/7a6cc325-e50f-42d5-96ca-b223593a43e6
# Room UUID: 41c4183c-f467-4d1a-bedc-79b2ce4a35e3
# ['hdowd@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/41c4183c-f467-4d1a-bedc-79b2ce4a35e3
# Room UUID: a2ecaf21-17c0-4395-b327-501f1831117d
# ['kroebuck@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/a2ecaf21-17c0-4395-b327-501f1831117d
# Room UUID: af462952-3c27-4f77-bb3e-326e29a5e066
# ['badili@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/af462952-3c27-4f77-bb3e-326e29a5e066
# Room UUID: 97a6a54d-ea1f-4d9a-86d1-6043c75c908c
# ['ywatanabe@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/97a6a54d-ea1f-4d9a-86d1-6043c75c908c
# Room UUID: f2d17af0-1342-4345-b1a3-ac2b8a6f9bef
# ['grwilliams@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f2d17af0-1342-4345-b1a3-ac2b8a6f9bef
# Room UUID: 3c615ca3-6e1f-4698-b433-69ffd2746bbd
# ['ndass@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/3c615ca3-6e1f-4698-b433-69ffd2746bbd
# Room UUID: d273ab3c-ea22-4b92-811b-bc5d5ae4e465
# ['grmurray@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace
g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/03caf419-ee61-4c6f-8903-34177b205a49
# Room UUID: 4895b52c-f2f2-4486-ac3e-ab816846f444
# ['ysugiyamalam@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/4895b52c-f2f2-4486-ac3e-ab816846f444
# Room UUID: d51b5418-049c-4bd6-b08a-05678c4cec3d
# ['avanderson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d51b5418-049c-4bd6-b08a-05678c4cec3d
# Room UUID: 47c4e939-5956-4814-afa8-86473ee48960
# ['kroy@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/47c4e939-5956-4814-afa8-86473ee48960
# Room UUID: 20e9aef0-321e-45f4-aa74-645cf48f0be5
# ['nfotenos@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/20e9aef0-321e-45f4-aa74-645cf48f0be5
# Room UUID: 540c60d4-4223-42a8-b516-6d7c78255985
# ['caperry@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/540c60d4-4223-42a8-b516-6d7c78255985
# Room UUID: 0f18505b-a0b1-4022-955f-88bf2c15872e
# ['lvlases@g.hmc.edu', 'avanluvanee@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/0f18505b-a0b1-4022-955f-88bf2c15872e
# Room UUID: 2039606e-3b2c-4554-b9e7-915bfeb471b9
# ['jheimann@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/2039606e-3b2c-4554-b9e7-915bfeb471b9
# Room UUID: 4c785db8-15c1-4bb2-9792-f868521958eb
# ['vkrishna@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/4c785db8-15c1-4bb2-9792-f868521958eb
# Room UUID: c33d7a2f-7475-4963-bb65-83239c42d56b
# ['tkidd@g.hmc.edu', 'lmcgraw@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/c33d7a2f-7475-4963-bb65-83239c42d56b
# Room UUID: b3e26ae5-3369-4208-8f38-a8ee47912c32
# ['eesqueda@g.hmc.edu', 'jvanderreis@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/b3e26ae5-3369-4208-8f38-a8ee47912c32
# Room UUID: daedc9df-8762-4fbb-9cba-8ae231efe494
# ['lmcdermott@g.hmc.edu', 'pmelendres@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/daedc9df-8762-4fbb-9cba-8ae231efe494
# Room UUID: f61e84ac-ee28-4487-a383-519264499132
# ['jmanese@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f61e84ac-ee28-4487-a383-519264499132
# Room UUID: d8ef3f32-0974-468b-b2ce-35f37d57ad61
# ['jgong@g.hmc.edu', 'kazhao@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d8ef3f32-0974-468b-b2ce-35f37d57ad61
# Room UUID: f3a52431-7f75-4980-af6d-5dc79623bb1a
# ['geverts@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f3a52431-7f75-4980-af6d-5dc79623bb1a
# Room UUID: 777c3b00-940c-46a5-8b4b-e5035eae0f81
# ['sijohnson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/777c3b00-940c-46a5-8b4b-e5035eae0f81
# Room UUID: 93df9880-f354-49b5-8780-95dc23a82c39
# ['echamplinwilson@g.hmc.edu', 'raczhang@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/93df9880-f354-49b5-8780-95dc23a82c39
# Room UUID: 8065cbcb-9c78-426b-adeb-63bdc2593b5b
# ['eschwartz@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/8065cbcb-9c78-426b-adeb-63bdc2593b5b
# Room UUID: 81f0194a-4c33-4250-a0d0-f40cacc6af91
# ['estralka@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/81f0194a-4c33-4250-a0d0-f40cacc6af91
# Room UUID: 0a20683c-261b-4188-97e2-7a931fe6b2f1
# ['lofowler@g.hmc.edu', 'ktrujillo@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/0a20683c-261b-4188-97e2-7a931fe6b2f1
# Room UUID: d043540c-d5e9-48cc-b84c-1446fbc08998
# ['natasmith@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d043540c-d5e9-48cc-b84c-1446fbc08998
# Room UUID: ca773d9f-661b-4fb6-8fcc-f92caed5cf10
# ['bdidrickson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/ca773d9f-661b-4fb6-8fcc-f92caed5cf10
# Room UUID: e086c4bc-cad6-4fbf-8ab1-31dbc041aabb
# ['mareeve@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e086c4bc-cad6-4fbf-8ab1-31dbc041aabb
# Room UUID: 386d281f-124d-46ef-b139-cc1add1ffa3e
# ['ihottenrott@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/386d281f-124d-46ef-b139-cc1add1ffa3e
# Room UUID: 0dfad04d-b044-4bf5-b444-38b9e007d80f
# ['zlevenberg@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/0dfad04d-b044-4bf5-b444-38b9e007d80f
# Room UUID: 1f5d9a06-b989-4a71-a8a2-6d9c1141c84b
# ['sbrewer@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/1f5d9a06-b989-4a71-a8a2-6d9c1141c84b
# Room UUID: 0d68e232-c00c-4487-bd65-2f165d4b0ce9
# ['sanarayanan@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/0d68e232-c00c-4487-bd65-2f165d4b0ce9
# Room UUID: 05c12e65-3570-4cff-85ef-b43878a6bcdd
# ['tjauhar@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/05c12e65-3570-4cff-85ef-b43878a6bcdd
# Room UUID: 18f643b6-9ce0-46c9-a748-2c681d457615
# ['ijain@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/18f643b6-9ce0-46c9-a748-2c681d457615
# Room UUID: 620ac223-847d-4303-85d0-1ecb03e5cbc6
# ['sgopalakrishnan@g.hmc.edu', 'asenapati@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/620ac223-847d-4303-85d0-1ecb03e5cbc6
# Room UUID: c2551c69-af83-43cf-8187-c4efee958a81
# ['asilver@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/c2551c69-af83-43cf-8187-c4efee958a81
# Room UUID: f61eafb0-8a32-4557-ae49-30c5e7dbf3c2
# ['lanfang@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f61eafb0-8a32-4557-ae49-30c5e7dbf3c2
# Room UUID: 79ddfcf3-ef90-4f8c-948f-5026c473df3d
# ['ankrishnan@g.hmc.edu', 'linnguyen@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/79ddfcf3-ef90-4f8c-948f-5026c473df3d
# Room UUID: 02d5940e-fe27-41f6-a51b-be3478d9b4c7
# ['mandrews@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/02d5940e-fe27-41f6-a51b-be3478d9b4c7
# Room UUID: d51956bb-4213-4ad1-99a7-0a83dbc947ef
# ['breis@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d51956bb-4213-4ad1-99a7-0a83dbc947ef
# Room UUID: fff9c8d3-8cb2-4943-b29d-96085f941861
# ['alezhu@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/fff9c8d3-8cb2-4943-b29d-96085f941861
# Room UUID: a06f8cbd-337f-4e68-9085-e0a50fd4d65a
# ['rhaapala@g.hmc.edu', 'smorishige@g.hmc.edu', 'rhaapala@g.hmc.edu', 'smorishige@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/a06f8cbd-337f-4e68-9085-e0a50fd4d65a
# Room UUID: 66bb542e-c5f5-4679-9204-cf86166bfb78
# ['nqazi@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/66bb542e-c5f5-4679-9204-cf86166bfb78
# Room UUID: fde655a9-9166-4752-af27-8357044940d2
# ['sellu@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/fde655a9-9166-4752-af27-8357044940d2
# Room UUID: f69e6248-485a-4d41-81e5-61cf842c370a
# ['avenkatachalam@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/f69e6248-485a-4d41-81e5-61cf842c370a
# Room UUID: 42eeb02a-4cad-4bad-936e-488b828c273f
# ['kahartman@g.hmc.edu', 'rerobinson@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace
g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e3c1cf82-1f67-4de7-a14c-b37f5d4ac5f0
# Room UUID: 729f8356-6a35-4369-ace9-b7c10e03dabb
# ['jilachinski@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/729f8356-6a35-4369-ace9-b7c10e03dabb
# Room UUID: d375529d-17cd-4e85-bbfe-f8da3af53ccd
# ['arajan@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/d375529d-17cd-4e85-bbfe-f8da3af53ccd
# Room UUID: 65e9aca3-e437-495e-abfb-ef8518366faf
# ['rsiguencia@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/65e9aca3-e437-495e-abfb-ef8518366faf
# Room UUID: 1b88d947-493e-408e-87eb-4a6721e2b982
# ['skantimahanty@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/1b88d947-493e-408e-87eb-4a6721e2b982
# Room UUID: acfc9b2a-b4f1-42d2-bff2-3d4834f0c6c2
# ['sgilats@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/acfc9b2a-b4f1-42d2-bff2-3d4834f0c6c2
# Room UUID: af8d634d-23ae-42a7-9b99-053defcf62ae
# ['aliyuan@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/af8d634d-23ae-42a7-9b99-053defcf62ae
# Room UUID: bc526da7-5413-4364-8904-d379bc44701d
# ['ekarissconyers@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/bc526da7-5413-4364-8904-d379bc44701d
# Room UUID: 3c04e850-c04c-400b-8b20-54e5bf6a77d3
# ['motraub@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/3c04e850-c04c-400b-8b20-54e5bf6a77d3
# Room UUID: ddca13a7-d907-40eb-9bf7-ec4c0ad13b6e
# ['hshuffelton@g.hmc.edu', 'wlomax@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/ddca13a7-d907-40eb-9bf7-ec4c0ad13b6e
# Room UUID: c024b0f0-1fd9-4273-95b9-8a92aa628498
# ['hkenyatta@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/c024b0f0-1fd9-4273-95b9-8a92aa628498
# Room UUID: e2f10572-7fe7-4f66-9fac-a5f5ac63548c
# ['eallgor@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e2f10572-7fe7-4f66-9fac-a5f5ac63548c
# Room UUID: e2e6cf06-4ec0-48bc-bd84-d9a6f6c2ce31
# ['elrogers@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e2e6cf06-4ec0-48bc-bd84-d9a6f6c2ce31
# Room UUID: 7974a43b-6c11-4325-a637-0aff9b5022f3
# ['abaik@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/7974a43b-6c11-4325-a637-0aff9b5022f3
# Room UUID: 9f8550b1-a646-49ff-95cf-b69161824a69
# ['ebarr@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/9f8550b1-a646-49ff-95cf-b69161824a69
# Room UUID: add3787b-392f-4568-b14c-ee11b9788f22
# ['cameyer@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/add3787b-392f-4568-b14c-ee11b9788f22
# Room UUID: e7e4376f-82af-4156-96e8-9e9087129915
# ['gseymour@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/e7e4376f-82af-4156-96e8-9e9087129915
# Room UUID: 3a5ab7e7-993b-49b7-a6fd-a7a73e9a9a63
# ['mmcmurray@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/3a5ab7e7-993b-49b7-a6fd-a7a73e9a9a63
# Room UUID: b34efa27-1a33-4ec7-9d28-2b32e641ffe1
# ['ehoorn@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/b34efa27-1a33-4ec7-9d28-2b32e641ffe1
# Room UUID: 9c243614-400a-492c-bf98-8d29231cda42
# ['dipark@g.hmc.edu']
# https://www.cs.hmc.edu/~tlam/digitaldraw/api/rooms/preplace/9c243614-400a-492c-bf98-8d29231cda42
# 2025-03-29 19:53:09,069| ERROR   | Socket exception: Connection reset by peer (104)
